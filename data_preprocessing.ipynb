# %% [markdown]
# # Predykcja i analiza cen samochodów

# %% [markdown]
# ## Cel Konkursu: opracowanie modelu predykcyjnego umożliwiającego precyzyjne przewidywanie cen pojazdów

# %% [markdown]
# ## Wstępne przetwarzanie danych

# %% [markdown]
# ## Wstępne przetwarzanie danych

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %% [markdown]
# ## Wgrywanie zbiorów danych

# %%
train_dataset = pd.read_csv('sales_ads_train.csv')
test_dataset = pd.read_csv('sales_ads_test.csv')

# %% [markdown]
# ### Połączenie obu zbiorów dla zachowania spójności preprocessingu

# %%
# Dodanie kolumny do odrónienia train od test
train_dataset["is_train"] = 1
test_dataset["is_train"] = 0

# Połączenie zbiorów
full_dataset = pd.concat([train_dataset, test_dataset], ignore_index=True)

# %%
# Wypisanie unikalnych wartości dla każdej kolumny
for column in full_dataset.columns:
    print(f"Kolumna: {column}")
    print(full_dataset[column].unique())
    print("-" * 50)
# Out:
# Kolumna: ID
# [     1      2      3 ... 135395 135396 135397]
# --------------------------------------------------
# Kolumna: Cena
# [ 13900.  25900.  35900. ... 677900. 269855.     nan]
# --------------------------------------------------
# Kolumna: Waluta
# ['PLN' nan 'EUR']
# --------------------------------------------------
# Kolumna: Stan
# ['Used' 'New' nan]
# --------------------------------------------------
# Kolumna: Marka_pojazdu
# ['Renault' 'Opel' 'Ford' 'Toyota' 'BMW' 'Audi' 'Volkswagen' 'Hyundai'
#  'Kia' 'Nissan' 'Dacia' 'Mazda' 'Volvo' 'Daewoo' 'Fiat' 'Jaguar' 'Škoda'
#  'Mitsubishi' 'Peugeot' 'Seat' 'Porsche' 'Honda' 'Jeep' nan 'Citroën'
#  'Mercedes-Benz' 'Chevrolet' 'Subaru' 'MINI' 'Alfa Romeo' 'DS Automobiles'
#  'Smart' 'Suzuki' 'Buick' 'Ferrari' 'Saab' 'Land Rover' 'Lancia'
#  'Cadillac' 'Infiniti' 'Aixam' 'Chrysler' 'SsangYong' 'Lexus' 'Dodge'
#  'McLaren' 'Gaz' 'Lada' 'Triumph' 'Lincoln' 'Daihatsu' 'Pontiac' 'Rover'
#  'Hummer' 'Tesla' 'Chatenet' 'Wołga' 'Microcar' 'Cupra' 'Maserati' 'RAM'
#  'Isuzu' 'MG' 'Warszawa' 'Polonez' 'Acura' 'Moskwicz' 'Rolls-Royce'
#  'Ligier' 'Abarth' 'Inny' 'Bentley' 'Trabant' 'Austin' 'Mercury' 'DFSK'
#  'Aston Martin' 'GMC' 'DKW' 'Tarpan' 'Uaz' 'FAW' 'Lotus' 'Plymouth' 'Tata'
#  'Żuk' 'Zastava' 'Alpine' 'Tavria' 'Casalini' 'Oldsmobile' 'Iveco'
#  'Lamborghini' 'Syrena' 'Vauxhall' 'Wartburg' 'Grecav' 'Baic'
#  'Autobianchi' 'Nysa' 'Vanderhall' 'Zaporożec' 'Saturn' 'MAN' 'NSU'
#  'Maybach' 'Santana' 'Scion' 'Talbot']
# --------------------------------------------------
# Kolumna: Model_pojazdu
# ['Grand Espace' 'Megane' 'Zafira' ... 'TR3' 'Arnage' 'GTC4Lusso']
# --------------------------------------------------
# Kolumna: Wersja_pojazdu
# ['Gr 2.0T 16V Expression' '1.6 16V 110'
#  'Tourer 1.6 CDTI ecoFLEX Start/Stop' ... '1.4 TB Sprint'
#  'Twin Top 2.0 Turbo' '2.0 TDI Xcellence Start/Stop']
# --------------------------------------------------
# Kolumna: Generacja_pojazdu
# [nan 'III (2008-2016)' 'C (2011-2019)' 'Mk2 (2004-2011)' 'III (2009-)'
#  'F15 (2013-2018)' 'C7 (2011-2018)' 'III (2009-2013)' 'B8 (2007-2015)'
#  'VIII (2020-)' 'V (2003-2009)' '8V (2012-)' 'II (2015-)' 'I (2009-2014)'
#  'B6 (2005-2010)' 'I (2007-2013)' 'II (2005-2011)' 'IV (1997-2006)'
#  'III (2012-)' 'II (2017-)' 'II (2016-)' 'K (2015-)' 'X260 (2015-)'
#  'Mk3 (2010-)' 'III (2013-)' 'IV (2010-)' 'E81/E82/E87/E88 (2004-2013)'
#  'C (2002-2008)' 'T7 (2008-2013)' 'F25 (2010-)' 'II (2013-)' 'II (2010-)'
#  'III (2014-)' 'VIII (2007-)' 'II (2002-2008)' 'II (2003-2009)'
#  'II (2007-)' 'I (2000-2010)' 'V (2019-)' 'III (2016-)' 'III (2001-2008)'
#  'III (2006-)' 'I (2006-2012)' '996 (1997-2004)' 'E39 (1996-2003)'
#  'E (2014-2019)' 'A (2008-2017)' 'II (2001-2014)' 'X164 (2006-2012)'
#  'Seria E21 (2019-)' 'II (2008-2018)' 'IV (2012-2018)' 'FY (2017-)'
#  'T9 (2014-)' 'D4 (2010-)' 'E83 (2003-2010)' 'III (2002-2008)'
#  'III (2017-)' 'W212 (2009-2016)' 'II (1993-1999)' 'I (2004-2012)'
#  'D (2006-2014)' 'VII (2002-2008)' 'B7 (2004-2007)' 'F30/F31 (2012-)'
#  'I (2001-2005)' '8T (2007-2016)' 'III (2008-2014)' 'III (2015-)'
#  'V (2015-)' 'IV (2019-)' 'W205 (2014-)' 'I (2005-2014)' 'III (2008-)'
#  'T4' 'II (2007-2013)' 'Mk2 (2006-2015)' 'Mk5 (2014-)' 'Z30 (2004-2012)'
#  'II (2004-2012)' 'II (2005-)' 'IV (2016-)' 'I (1997-2002)'
#  'I (2009-2016)' 'II (2012-)' 'II (2002-2010)' 'Mk4 (2007-2014)'
#  'GR II Y61 (1997-)' 'I (2004-2006)' 'C219 (2004-2010)'
#  'F12/F13/F14 (2011-)' 'I (2002-2009)' 'W211 (2002-2009)'
#  'E90/E91/E92/E93 (2005-2012)' 'B5 FL (2000-2005)' 'E36 (1990-1999)'
#  'I (2008-2017)' '8P (2003-2012)' 'VII (2012-2020)' 'E84 (2009-2015)'
#  'C6 (2004-2011)' 'B7 (2010-2014)' 'Mk4 (2018-)' '991 (2011-2018)'
#  'B6 (2000-2004)' 'III (2006-2012)' 'III (2003-2010)' 'Mk6 (2002-2008)'
#  'B8 (2014-)' 'F48 (2015-)' 'III (2010-2015)' 'J (2009-2015)'
#  'I (2007-2012)' 'I (2003-2010)' 'II (2015-2019)' 'D3 (2002-2010)'
#  'W140 (1992-1998)' 'I (2004-2010)' 'II (2019-)' 'IV (2020-)'
#  'I (2002-2010)' 'I (2006-2015)' 'E46 (1998-2007)' 'E60/E61 (2003-2010)'
#  'II (2011-)' 'E65/66 (2001-2008)' 'W166 (2015-2019)' 'II (2004-2013)'
#  '8R (2008-2016)' 'W204 (2007-2014)' 'II (2003-2011)' 'I (1996-2011)'
#  'W245 (2005-2011)' 'T6' 'Mk3 (2015-)' 'VI (2008-2013)' 'F (1991-2002)'
#  'Mk7 (2008-)' 'VI (2010-)' 'I (2001-2014)' 'III (2007-)' 'H (2004-2014)'
#  'W203 (2000-2007)' 'II (2003-2012)' 'Seria E12 (2001-2007)'
#  'I (2009-2017)' 'II (2001-2007)' 'R129 (1989-2000)' 'I (2001-2004)'
#  'II (2005-2014)' 'F20/F21 (2011-)' 'F10/F11 (2009-2017)' 'II FL (2003-)'
#  'C5 (1997-2004)' 'VIII (2006-2011)' 'W166 (2011-2015)' 'G30/G31 (2017-)'
#  'VII (2001-2006)' 'VIII (2008-2015)' 'IV (2001-2009)' 'IX (2011-)'
#  'E71 (2008-2014)' 'II (2007-2014)' 'I (2006-2013)' 'I (2007-2016)'
#  'IV (2004-2010)' 'W463 (1992-2018)' 'I (1993-2001)' 'IV (2013-)'
#  'III (1991-1998)' 'W213 (2016-)' 'I (1998-2006)' 'B (2017-)'
#  'P12 (2001-2007)' 'I (1999-2008)' 'III (2004-)' 'VI (1998-2002)'
#  'Seria E16 (2012-2019)' 'E53 (1999-2006)' 'T1' 'IV (2008-2017)'
#  '8L (1996-2003)' 'A6 (2010-)' 'X250 (2007-2015)' 'G11/12 (2015-)'
#  'I (2010-2019)' 'III (2004-2009)' 'I (1998-2008)' 'C215 (1999-2006)'
#  'I (2003-2009)' 'F26 (2014–2018)' 'W168 (1997-2004)' 'I (1995-2004)'
#  'C (2000-2006)' 'G05 (2018-)' 'I (2002-2008)' 'G20 (2019-)' 'B9 (2015-)'
#  'III (2019-)' 'E8 i starsze (-1987)' 'W176 (2012-)' 'C8 (2019-)'
#  'II (2014-)' 'III (2011-)' 'E70 (2006-2013)' 'IV (2003-2014)'
#  'W177 (2018-)' 'G06 (2019-)' 'W221 (2005-)' 'A (1999-2005)'
#  'I (2008-2012)' 'I (1999-2005)' 'B (1993-2000)' 'W222 (2013-)'
#  'III (2005-2010)' 'V (2018-)' 'III (2019 - )' 'III (2000-2006)'
#  'I (2005-2015)' 'B5 (1996-2000)' 'W247 (2018-)' 'Mk8 (2017-)'
#  'K13 (2010-2016)' 'II (2009-2013)' 'II (2006-2013)' 'I (1998-2005)'
#  'II (2006-2012)' 'G (1998-2009)' 'C257 (2018-)' 'F40 (2019-)'
#  'II (1998-2012)' 'II (2001-)' 'GH (2007-)' 'I (2001-2008)'
#  'II (2000-2005)' 'F16 (2014-)' 'III (2005-2012)' 'II (2005-2012)'
#  'V (2020-)' 'X (2017-)' 'C8 (2018-)' 'T5' 'V (2014-)' 'III (2001-2006)'
#  'D (2011-2018)' 'B (2005-2014)' 'III (2001-)' 'I (1997-2006)'
#  'I (1996-2002)' 'IV (2015-2020)' 'II (2010-2015)' 'C6 (2006-2011)'
#  'Mk3 (2000-2006)' 'K12 (2003-2010)' 'V (2010-2017)' 'II (2009-)'
#  'C7 (2012-)' 'W163 (1998-2005)' 'IV (2020 - )' 'GC (1992-2001)'
#  'W210 (1995-2002)' 'W124 (1993-1997)' 'G07 (2019-)' 'W221 (2005-2013)'
#  'W167 (2019-)' 'W246 (2011-2018)' 'I (2000-2005)' 'V (2008–2015)'
#  'VII (2013-)' 'I (2001-2006)' 'B5 (1995-2001)' 'B (1995-2002)'
#  'II (2004-2010)' 'I (2005-2010)' 'V (2017-)' 'GD (2001-2007)'
#  'II (1999-2007)' 'R171 (2004-2011)' 'I (1988-1999)'
#  'Seria E11 (1997-2002)' 'IV (2007-)' 'I (2005-2013)' 'K14 (2017-)'
#  'III (2018-)' 'R170 (1996-2004)' 'W126 (1980-1993)' 'I (1996-2010)'
#  'A5 (2005-2010)' 'C216 (2006-2013)' 'I (2013-2019)' 'Mk2 (2000-2005)'
#  'X351 (2009-)' 'II (1999-2004)' 'W208 (1997-2002)' 'III (2009-2015)'
#  'Seria E15 (2007-2013)' 'III (1994-2001)' 'Z50 (2003-2008)'
#  'II (1995-2000)' 'E63/E64 (2002-2010)' 'R107 (1972-1989)' 'II (2006-)'
#  'III (2020-)' 'V (2009-2014)' 'B4 (1993-1997)' 'B (2008-2014)'
#  'Mk1 (1998-2004)' 'III (1996-2002)' 'VIII (1996-2006)' 'II (2008-)'
#  'II (1987-2001)' 'G01 (2017-)' 'I (1995-2001)' 'VI (2017-)' 'VI (2006-)'
#  'N16 (2000-2006)' 'GLK 220' 'IV (2007-2010)' 'P11 (1996-2002)'
#  'E34 (1988-1996)' 'W169 (2004-2012)' 'I (1990-1998)' 'I (2002-2014)'
#  'B3 (1986-1991)' 'I (2008-2013)' 'W209 (2002-)' 'I (1995-2010)'
#  'E (2018-)' 'II (1989-1997)' 'II (1992-1997)' 'I (1998-2002)'
#  '993 (1993-1997)' 'R230 (2001-2013)' 'F5 (2016-)' 'I (1993-2007)'
#  'I (1998-2007)' '8J (2006-2013)' 'IV (2006-)' 'II (2001-2006)'
#  'IX (2005-2008)' 'IV (2009-2015)' 'II (2004-2008)' 'W447 (2014-)'
#  'II (2001-2004)' 'IV (2018-)' '8Y (2020 - )' 'W164 (2005-2011)'
#  'D (2019-)' 'I (1996-2003)' 'W639 (2003-2014)' 'III (2008-2012)'
#  'I (2008-2014)' 'I (2002-2013)' 'D5 (2017-)' 'C5 (1999-2005)'
#  'F01 (2008-2015)' 'Mark I (1968-1992)' 'D2 (1994-2002)' 'F (2019-)'
#  'E31 (1989-1999)' 'G02 (2018-)' 'Mk7 (1995-1999)' 'III (2001-2012)'
#  'E85/E86 (2002-2008)' 'III (2004-2011)' 'II (1999-2003)' 'II (2004-2009)'
#  'VI (1995-2001)' 'I (1997-2003)' 'E38 (1994-2001)' 'Z51 (2008-)' 'T2'
#  'IV (2017-)' 'II (1998-2004)' 'I (1996-2006)' 'B4 (1991-1995)'
#  '992 (2019-)' 'I (2001-2007)' 'II (1983-1992)' 'III (1998-2003)'
#  'C4 (1994-1997)' 'III (2005-2009)' 'I (2000-2006)' '8S (2014-)'
#  'C (1973-1979)' 'X350 (2004-2007)' 'B FL (1999-2003)' '997 (2005-2011)'
#  '8N (1998-2006)' 'W202 (1993-2001)' 'Mk4 (1996-1999)' 'I (1996-2008)'
#  'IV (2003-2009)' 'II (1990-2000)' 'II FL (1999-2002)' 'Mk1 (1995-2005)'
#  'X166 (2012-)' 'GLK 350' 'C218 (2011-)' 'B2 (1978-1986)' 'I (1974-1983)'
#  'I (1980-2003)' 'K10 (1982-1992)' 'W220 (1998-2005)' 'A2 (1984-1992)'
#  'II (2002-2006)' 'II (1997-2006)' 'I (1989-1996)' 'K11 (1992-2003)'
#  'II (1980-1986)' 'I (1995-2000)' 'R231 (2012-)' 'A (2000-2007)'
#  'VII (2003-2008)' 'II (1994-2006)' 'C4 (1991-1994)' 'IV (2002-2009)'
#  'I (1994-2001)' 'E12 (1972-1981)' 'I (1997-2000)' 'B1 (1973-1981)'
#  'GLK 320' 'B (1998-2004)' 'V (2019 - )' 'I (2003-2007)' 'E30 (1982-1994)'
#  'I (1981-1990)' 'Mk2 (1987-1993)' 'II (2009-2015)' 'I (1991-1999)'
#  'IX (2012-2018)' 'X300 (1994-1997)' 'I (1994-2000)' 'G14/G15/G16 (2018-)'
#  'G29 (2018-)' 'R172 (2011-)' 'T3' 'Inny' 'C (2001-2011)'
#  '930 (1983-1990)' 'B (1994-2000)' 'Mk6 (1992-1995)' 'II (2000-2004)'
#  'E89 (2009–2016)' 'I (1997-2001)' 'B3 (1988-1993)' 'I (1989-1998)'
#  'II (1994-1998)' 'C140 (1992-1998)' 'Mk1 (1982-1986)' 'A (1992-1998)'
#  'II (1995-)' 'IV (1994-2000)' 'I FL (1999-2002)' 'IV (1987-1991)'
#  'II (1981-1994)' 'GR I Y60 (1987-1997)' 'Mk2 (1996-2000)' 'V (2000-2006)'
#  'VII (1992-1997)' 'III (1996-2004)' 'E (1984-1994)' 'XJ40 (1986-1994)'
#  'I (1994-2006)' 'II (1997-2004)' 'VI (2020 - )' 'G32 (2017-)'
#  'Mk5 (1999-2002)' 'V (1991-1996)' 'II (1998-2003)' 'I (1996-2007)'
#  'E32 (1986-1994)' 'III (1983-1987)' 'W638 (1996-2003)' 'W116 (1972-1980)'
#  'X358 (2007-2009)' 'III (1997-2003)' 'CJ0 (1995-2003)'
#  'Seria E10 (1992-1997)' 'E28 (1981-1987)' 'Mk5 (1990-1992)'
#  'X308 (1997-2003)' 'C1 (1968-1976)' 'E23 (1977-1986)' 'W483 (2018-)'
#  'E21 (1975-1982)' 'II (2003-2010)' 'E24 (1976-1989)' 'I (1993-1999)'
#  'CA0 (1992-1995)' 'GLK 250' 'N15 (1995-2000)' 'II (1983-1985)'
#  'II (2000-2006)' 'Mk4 (1986-1990)' 'Mk3 (1980-1986)' 'I (1995-1999)'
#  'II (1978-1986)' 'III (2010-)' 'VI (1996-2003)' 'Mk1 (1985-1994)'
#  'IV (2008-2013)' 'II (1989-)' '114' 'II (1994-2001)' 'E (1992-1997)'
#  'VI (2014-)' 'I (1991-1996)' 'A (1988-1995)' 'V (1993-1998)'
#  'V (2008-2010)' '60.0' 'II (1995-2003)' 'II (1993-1997)' 'I (1994-1999)'
#  'Mk1 (1993-1996)' 'VI (1987-1992)' '964 (1989-1994)' 'II (1983-1987)'
#  'II (1995-2001)' 'Seria E9 (1987-1992)' 'B2 (1981-1987)'
#  'W460 (1979-1992)' 'I (1981-1993)' 'V (1997-2001)' 'VI (1998-2003)'
#  'I (1987-1995)' 'I (1994-2002)' 'A1 (1980-1984)' 'I (1983-1993)'
#  'I (2000-2002)' 'II (1996-2006)' 'B (1994-1999)' 'II (1996-2000)'
#  'V (1994-1998)' 'C2 (1976-1982)' 'C10 (1984-1988)' 'C3 (1982-1991)'
#  'III (1986-1989)' 'IV (1990-1993)' 'I (1988-1992)' 'I (1993-1998)'
#  'I (1995-2005)' 'I (1970-1994)' 'B12/N13 (1986-1991)' 'IV (1989-1994)'
#  'P10/W10 (1990-1998)' '9' 'VI (2020-)' 'III (1986-1994)' 'I (1982-1990)'
#  'II (1998-2001)' 'Mk3 (1989-1996)' 'I (1989-1994)' 'II (1995-1999)'
#  'I (1989-1992)' 'I (1999-2003)' 'II (2000 - 2003)' 'IV (1992-1997)'
#  'A (1982-1993)' 'II (1979-1983)' 'II (1994-1999)' 'Mk1 (1977-1983)'
#  'I (1985-1994)' 'II (1998-2005)' 'I (1975-1981)' 'III (1985-1989)'
#  'Mk2 (1994-1998)' 'B13/N14 (1990-1995)' 'III (1999-2006)']
# --------------------------------------------------
# Kolumna: Rok_produkcji
# [2005. 2010. 2015. 2007. 2013. 2014. 2016. 2011. 2009. 2021. 2006. 2017.
#  2004. 2020.   nan 2008. 2012. 2002. 1989. 2000. 2019. 1997. 2018. 2003.
#  2001. 1994. 1995. 1991. 1998. 1999. 1996. 1966. 1986. 1963. 1965. 1992.
#  1968. 1979. 1981. 1964. 1934. 1971. 1985. 1988. 1993. 1980. 1990. 1957.
#  1987. 1983. 1967. 1969. 1958. 1984. 1953. 1973. 1972. 1978. 1961. 1975.
#  1956. 1959. 1977. 1974. 1952. 1954. 1938. 1962. 1960. 1970. 1947. 1976.
#  1936. 1982. 1955. 1923. 1950. 1928. 1949. 1924. 1926. 1951. 1935. 1930.
#  1927. 1948. 1945. 1937. 1925. 1946. 1915. 1922. 1933.]
# --------------------------------------------------
# Kolumna: Przebieg_km
# [213000. 117089. 115600. ... 218031. 178643.  76786.]
# --------------------------------------------------
# Kolumna: Moc_KM
# [1.700e+02 1.100e+02 1.360e+02 9.000e+01       nan 2.580e+02 1.900e+02
#  1.050e+02 1.150e+02 1.430e+02 1.500e+02 5.750e+02 1.160e+02 1.400e+02
#  1.000e+02 7.200e+01 1.750e+02 1.630e+02 1.970e+02 2.200e+02 9.500e+01
#  1.450e+02 1.010e+02 1.350e+02 1.200e+02 1.060e+02 1.090e+02 9.200e+01
#  1.840e+02 1.580e+02 2.000e+02 4.400e+02 1.250e+02 8.600e+01 1.470e+02
#  2.500e+02 8.500e+01 1.620e+02 3.000e+02 1.600e+02 1.800e+02 2.310e+02
#  1.140e+02 3.060e+02 6.500e+01 1.320e+02 7.500e+01 1.650e+02 4.350e+02
#  8.000e+01 2.400e+02 6.000e+01 8.700e+01 2.550e+02 6.900e+01 7.000e+01
#  1.520e+02 5.100e+02 1.770e+02 1.860e+02 3.400e+02 6.800e+01 1.300e+02
#  2.870e+02 1.460e+02 1.410e+02 1.290e+02 2.530e+02 1.220e+02 1.270e+02
#  2.600e+02 2.240e+02 4.490e+02 1.730e+02 6.400e+01 1.930e+02 2.040e+02
#  6.700e+02 2.450e+02 4.300e+02 1.120e+02 8.400e+01 4.210e+02 2.720e+02
#  1.040e+02 5.500e+01 3.260e+02 3.700e+02 7.100e+01 3.200e+02 2.800e+02
#  2.330e+02 1.560e+02 7.700e+01 2.100e+02 5.300e+02 2.180e+02 6.700e+01
#  3.670e+02 3.410e+02 1.790e+02 1.020e+02 1.920e+02 8.200e+01 3.850e+02
#  2.130e+02 1.170e+02 5.400e+01 1.490e+02 1.240e+02 3.660e+02 9.700e+01
#  9.900e+01 1.780e+02 1.180e+02 1.380e+02 2.380e+02 1.830e+02 1.280e+02
#  1.950e+02 2.350e+02 1.420e+02 2.620e+02 2.520e+02 1.940e+02 2.300e+02
#  2.110e+02 3.050e+02 1.230e+02 5.000e+02 9.800e+01 3.500e+02 1.870e+02
#  8.300e+01 4.400e+01 4.100e+01 3.100e+02 4.200e+02 4.500e+02 4.120e+02
#  7.600e+01 3.810e+02 2.760e+02 6.000e+02 1.110e+02 2.860e+02 3.130e+02
#  3.550e+02 1.550e+02 3.880e+02 8.000e+00 2.250e+02 2.030e+02 7.800e+01
#  3.330e+02 1.590e+02 3.720e+02 2.750e+02 3.300e+02 2.830e+02 1.070e+02
#  3.800e+02 4.920e+02 3.170e+02 3.030e+02 3.440e+02 2.120e+02 2.950e+02
#  3.340e+02 2.660e+02 1.820e+02 9.100e+01 1.740e+02 2.770e+02 2.540e+02
#  3.960e+02 2.920e+02 1.850e+02 1.610e+02 7.300e+01 2.010e+02 4.070e+02
#  2.150e+02 1.210e+02 1.710e+02 2.650e+02 2.890e+02 3.490e+02 3.450e+02
#  2.910e+02 6.300e+01 6.080e+02 3.320e+02 5.000e+00 4.090e+02 2.390e+02
#  4.320e+02 4.060e+02 6.600e+01 1.260e+02 4.800e+01 2.700e+02 5.500e+02
#  1.310e+02 1.660e+02 3.470e+02 1.810e+02 8.800e+01 1.960e+02 6.390e+02
#  5.250e+02 3.350e+02 3.500e+01 6.120e+02 6.100e+01 3.900e+02 2.340e+02
#  5.000e+01 2.230e+02 4.000e+02 2.050e+02 3.590e+02 5.200e+01 4.790e+02
#  9.400e+01 6.800e+02 4.500e+01 1.880e+02 2.900e+02 3.230e+02 2.320e+02
#  3.000e+01 2.840e+02 3.600e+02 4.050e+02 2.690e+02 2.170e+02 2.370e+02
#  9.600e+01 3.620e+02 2.850e+02 2.500e+01 7.170e+02 5.850e+02 2.490e+02
#  1.640e+02 6.200e+01 1.910e+02 5.700e+02 3.080e+02 3.760e+02 3.940e+02
#  5.800e+01 4.010e+02 2.100e+01 2.420e+02 5.070e+02 2.070e+02 3.040e+02
#  3.820e+02 2.080e+02 4.310e+02 3.090e+02 9.300e+01 2.220e+02 4.000e+00
#  4.680e+02 1.440e+02 4.080e+02 1.030e+02 3.180e+02 3.750e+02 2.990e+02
#  4.550e+02 1.130e+02 3.650e+02 1.340e+02 5.200e+02 2.210e+02 2.510e+02
#  3.190e+02 2.140e+02 5.600e+02 2.410e+02 1.690e+02 2.930e+02 3.900e+01
#  2.790e+02 2.360e+02 2.400e+01 1.330e+02 2.440e+02 3.520e+02 2.480e+02
#  2.680e+02 1.760e+02 1.390e+02 2.610e+02 4.100e+02 1.990e+02 2.640e+02
#  5.140e+02 3.950e+02 3.390e+02 3.540e+02 3.280e+02 5.910e+02 7.900e+01
#  7.610e+02 8.100e+01 3.150e+02 4.800e+02 7.400e+01 3.970e+02 3.110e+02
#  4.530e+02 3.430e+02 1.510e+02 3.740e+02 5.710e+02 1.190e+02 6.240e+02
#  3.400e+01 4.150e+02 1.680e+02 4.890e+02 4.220e+02 1.670e+02 1.000e+00
#  2.430e+02 4.570e+02 4.600e+02 2.630e+02 5.900e+01 6.350e+02 2.280e+02
#  6.750e+02 3.250e+02 3.140e+02 2.940e+02 1.370e+02 3.800e+01 2.960e+02
#  3.530e+02 2.800e+01 3.070e+02 2.560e+02 6.050e+02 4.900e+02 6.250e+02
#  5.170e+02 4.290e+02 2.260e+02 4.300e+01 3.310e+02 2.900e+01 4.560e+02
#  3.210e+02 1.980e+02 3.010e+02 1.530e+02 1.080e+02 2.980e+02 5.810e+02
#  3.600e+01 2.470e+02 4.760e+02 5.700e+01 2.730e+02 3.870e+02 4.650e+02
#  2.200e+01 5.180e+02 3.710e+02 6.590e+02 2.970e+02 1.111e+03 2.820e+02
#  6.460e+02 1.540e+02 2.780e+02 4.200e+01 6.300e+02 1.200e+01 3.220e+02
#  1.480e+02 4.620e+02 2.090e+02 3.120e+02 8.900e+01 7.970e+02 2.880e+02
#  6.100e+02 4.970e+02 3.020e+02 2.020e+02 7.100e+02 5.030e+02 7.400e+02
#  6.000e+00 2.570e+02 2.600e+01 3.510e+02 5.550e+02 5.300e+01 2.740e+02
#  5.400e+02 2.460e+02 1.890e+02 6.110e+02 6.320e+02 3.830e+02 5.150e+02
#  5.100e+01 5.580e+02 2.000e+01 1.570e+02 2.300e+01 4.870e+02 6.030e+02
#  5.800e+02 4.410e+02 7.000e+00 3.770e+02 4.160e+02 6.980e+02 3.290e+02
#  4.660e+02 4.700e+02 1.100e+01 4.420e+02 5.390e+02 3.270e+02 3.990e+02
#  4.000e+01 4.640e+02 4.450e+02 3.100e+01 4.590e+02 4.250e+02 4.690e+02
#  5.230e+02 6.500e+02 4.750e+02 2.270e+02 5.600e+01 2.700e+01 5.440e+02
#  7.000e+02 5.990e+02 4.280e+02 5.120e+02 4.040e+02 5.040e+02 5.220e+02
#  4.810e+02 1.500e+01 3.160e+02 2.060e+02 9.070e+02 3.360e+02 1.720e+02
#  2.710e+02 2.810e+02 5.490e+02 4.260e+02 6.200e+02 3.640e+02 5.630e+02
#  3.630e+02 4.820e+02 4.230e+02 7.210e+02 5.690e+02 1.800e+01 5.570e+02
#  1.102e+03 3.860e+02 5.320e+02 7.150e+02 5.190e+02 6.180e+02 4.480e+02
#  5.640e+02 5.370e+02 5.080e+02 4.030e+02 4.850e+02 2.670e+02 5.160e+02
#  6.130e+02 1.000e+01 7.200e+02 6.090e+02 4.520e+02 7.300e+02 4.600e+01
#  5.610e+02 5.840e+02 3.700e+01 3.300e+01 3.610e+02 6.400e+02 4.020e+02
#  5.210e+02 7.230e+02 6.210e+02 6.900e+02 4.700e+01 1.700e+01 4.990e+02
#  2.000e+00 4.630e+02 8.000e+02 1.900e+01 1.236e+03 4.510e+02 4.770e+02
#  5.510e+02 1.600e+01 3.920e+02 2.290e+02 5.280e+02 5.060e+02 6.600e+02
#  3.780e+02 6.420e+02 7.700e+02 5.980e+02 4.900e+01 4.170e+02 3.200e+01
#  3.790e+02 7.500e+02 4.180e+02 2.590e+02 5.110e+02 3.890e+02 9.000e+00
#  5.050e+02 1.203e+03 5.650e+02 5.340e+02 3.240e+02 1.398e+03 5.260e+02
#  3.570e+02 3.680e+02 5.480e+02 1.115e+03 4.720e+02 7.740e+02 8.850e+02
#  4.110e+02 4.360e+02 7.070e+02 5.670e+02 4.950e+02 1.000e+03 5.330e+02
#  4.140e+02 7.050e+02 5.770e+02 5.540e+02 2.190e+02 7.350e+02 5.310e+02
#  4.430e+02 3.980e+02 1.300e+03 7.160e+02 7.600e+02 3.000e+00 3.730e+02]
# --------------------------------------------------
# Kolumna: Pojemnosc_cm3
# [1998. 1598. 1560. ... 6800. 1829. 2469.]
# --------------------------------------------------
# Kolumna: Rodzaj_paliwa
# ['Gasoline' nan 'Diesel' 'Gasoline + LPG' 'Hybrid' 'Electric'
#  'Gasoline + CNG' 'Hydrogen' 'Ethanol']
# --------------------------------------------------
# Kolumna: Emisja_CO2
# [2.32000e+02 1.59000e+02         nan 1.18000e+02 1.52000e+02 1.13000e+02
#  1.44000e+02 2.58000e+02 1.10000e+02 1.80000e+02 1.09000e+02 9.90000e+01
#  1.77000e+02 1.74000e+02 1.54000e+02 1.91000e+02 1.55000e+02 1.41000e+02
#  2.17000e+02 1.45000e+02 1.29000e+02 3.20000e+01 1.50000e+02 2.03000e+02
#  1.39000e+02 1.37000e+02 1.05000e+02 2.07000e+02 1.24000e+02 1.71000e+02
#  1.84000e+02 1.48000e+02 1.53000e+02 1.31000e+02 1.28000e+02 2.38000e+02
#  1.21000e+02 1.27000e+02 1.25000e+02 1.23000e+02 1.70000e+02 1.06000e+02
#  1.49000e+02 1.15000e+02 1.62000e+02 1.89000e+02 1.17000e+02 1.26000e+02
#  1.96000e+02 1.14000e+02 1.65000e+02 1.34000e+02 1.38000e+02 2.06000e+02
#  2.96000e+02 1.46000e+02 9.50000e+01 1.73000e+02 1.99000e+02 1.22000e+02
#  2.12000e+02 2.00000e+02 1.93000e+02 1.47000e+02 2.89000e+02 1.20000e+02
#  1.03000e+02 2.49000e+02 1.07000e+02 1.16000e+02 2.30000e+02 1.32000e+02
#  2.18000e+02 9.70000e+01 1.75000e+02 1.88000e+02 1.43000e+02 2.40000e+02
#  1.90000e+02 1.33000e+02 1.79000e+02 9.00000e+01 1.51000e+02 1.85000e+02
#  1.69000e+02 9.80000e+01 4.00000e+01 1.61000e+02 1.40000e+02 1.60000e+02
#  1.36000e+02 1.56000e+02 1.04000e+02 2.44000e+02 1.00000e+02 1.72000e+02
#  1.92000e+02 1.30000e+02 2.01000e+02 1.94000e+02 1.19000e+02 1.86000e+02
#  1.57000e+02 1.42000e+02 1.11000e+02 2.05000e+02 9.30000e+01 1.35000e+02
#  1.98000e+02 2.25000e+02 1.78000e+02 1.67000e+02 3.78000e+02 1.81000e+02
#  8.50000e+01 8.20000e+01 1.08000e+02 1.58000e+02 1.87000e+02 1.64000e+02
#  2.15000e+02 6.00000e+00 2.63000e+02 2.55000e+02 2.22000e+02 3.19000e+02
#  2.64000e+02 1.63000e+02 9.20000e+01 2.78000e+02 1.95000e+02 1.02000e+02
#  1.83000e+02 2.24000e+02 9.40000e+01 3.33000e+02 2.04000e+02 6.66000e+02
#  2.14000e+02 2.28000e+02 2.70000e+02 1.01000e+02 1.00000e+00 2.21000e+02
#  9.10000e+01 8.70000e+01 2.19000e+02 2.53000e+02 8.40000e+01 4.40000e+01
#  2.76000e+02 2.33000e+02 2.02000e+02 2.00000e+00 1.66000e+02 8.90000e+01
#  1.97000e+02 3.83000e+02 1.68000e+02 2.26000e+02 4.80000e+01 2.13000e+02
#  9.60000e+01 2.82000e+02 2.88000e+02 3.55000e+02 1.12000e+02 2.29000e+02
#  2.62000e+02 2.11000e+02 2.35000e+02 4.90000e+01 2.95000e+02 1.82000e+02
#  8.10000e+01 2.67000e+02 1.76000e+02 2.31000e+02 2.80000e+01 5.50000e+01
#  2.80000e+02 2.23000e+02 2.46000e+02 2.20000e+02 2.42000e+02 3.52000e+02
#  2.37000e+02 2.91000e+02 8.80000e+01 2.52000e+02 2.10000e+02 3.32000e+02
#  2.60000e+02 2.75000e+02 3.30000e+02 4.60000e+01 2.65000e+02 2.34000e+02
#  4.00000e+00 3.26000e+02 3.28000e+02 2.45000e+02 5.00000e+01 4.20000e+01
#  3.70000e+01 2.79000e+02 2.51000e+02 2.16000e+02 7.70000e+01 2.27000e+02
#  2.84000e+02 2.47000e+02 2.54000e+02 2.08000e+02 3.94000e+02 2.09000e+02
#  7.00000e+01 3.04000e+02 8.30000e+01 3.10000e+01 3.50000e+01 3.05000e+02
#  2.48000e+02 2.50000e+02 3.45000e+02 2.98000e+02 3.08000e+02 2.90000e+01
#  1.30000e+01 2.77000e+02 2.59000e+02 3.57000e+02 3.30000e+01 3.63000e+02
#  2.68000e+02 2.66000e+02 2.90000e+02 7.50000e+01 5.00000e+00 7.90000e+01
#  4.30000e+01 2.70000e+01 3.40000e+01 2.69000e+02 3.16000e+02 3.22000e+02
#  3.35000e+02 3.07000e+02 2.56000e+02 8.60000e+01 5.10000e+01 4.50000e+01
#  2.61000e+02 2.83000e+02 3.13000e+02 3.29000e+02 2.36000e+02 2.43000e+02
#  3.17000e+02 2.92000e+02 2.39000e+02 5.60000e+01 2.41000e+02 2.99000e+02
#  2.86000e+02 2.94000e+02 5.20000e+01 4.70000e+01 2.57000e+02 3.06000e+02
#  2.71000e+02 6.60000e+01 4.10000e+01 3.10000e+02 7.20000e+01 3.96000e+02
#  7.60000e+01 3.64000e+02 1.60000e+01 3.25000e+02 3.54000e+02 3.24000e+02
#  2.00000e+01 6.40000e+01 3.27000e+02 3.88000e+02 3.92000e+02 2.74000e+02
#  3.70000e+02 3.38000e+02 3.15000e+02 3.80000e+01 3.23000e+02 3.47000e+02
#  2.72000e+02 3.66000e+02 3.09000e+02 3.00000e+01 3.80000e+02 3.95000e+02
#  1.20000e+01 5.90000e+01 3.42000e+02 3.03000e+02 2.87000e+02 3.44000e+02
#  1.00000e+01 3.58000e+02 2.81000e+02 3.90000e+01 3.61000e+02 2.73000e+02
#  2.20000e+01 3.31000e+02 3.00000e+02 3.20000e+02 3.12000e+02 3.59000e+02
#  3.48000e+02 4.00000e+02 7.10000e+01 3.40000e+02 3.84000e+02 3.85000e+02
#  2.97000e+02 1.19130e+05 3.46000e+02 2.85000e+02 3.00000e+00 1.25132e+05
#  3.53000e+02 6.50000e+01 3.37000e+02 4.10000e+02 8.00000e+00 3.60000e+01
#  3.50000e+02 3.51000e+02 2.60000e+01 6.90000e+01 1.90000e+01 4.88000e+02
#  3.39000e+02 3.60000e+02 3.62000e+02 2.00000e+10 3.41000e+02 1.80000e+01
#  4.90000e+02 4.15000e+02 4.07000e+02 4.23000e+02 3.11000e+02 2.93000e+02
#  4.06000e+02 4.95000e+02 3.34000e+02 3.01000e+02 3.97000e+02 7.80000e+01
#  3.65000e+02 3.82000e+02 2.50000e+01 3.14000e+02 3.02000e+02 6.20000e+01
#  3.43000e+02 1.40000e+01 4.50000e+02 5.55555e+05 1.00000e+10 1.00000e+06
#  3.71000e+02]
# --------------------------------------------------
# Kolumna: Naped
# ['Front wheels' nan '4x4 (permanent)' '4x4 (attached automatically)'
#  'Rear wheels' '4x4 (attached manually)']
# --------------------------------------------------
# Kolumna: Skrzynia_biegow
# ['Manual' 'Automatic' nan]
# --------------------------------------------------
# Kolumna: Typ_nadwozia
# ['minivan' 'station_wagon' 'compact' nan 'SUV' 'sedan' 'small_cars'
#  'coupe' 'city_cars' 'convertible']
# --------------------------------------------------
# Kolumna: Liczba_drzwi
# [ 5.  4.  3.  2. nan  6. 55.  1.  7. 10.  9.]
# --------------------------------------------------
# Kolumna: Kolor
# ['blue' 'silver' 'white' 'other' 'black' 'gray' 'golden' nan 'burgundy'
#  'brown' 'red' 'violet' 'beige' 'yellow' 'green']
# --------------------------------------------------
# Kolumna: Kraj_pochodzenia
# [nan 'Denmark' 'Poland' 'Germany' 'Austria' 'France' 'Belgium' 'Italy'
#  'Netherlands' 'Switzerland' 'United States' 'Spain' 'Other' 'Finland'
#  'Great Britain' 'Canada' 'Sweden' 'Ukraine' 'Czech Republic' 'Luxembourg'
#  'Ireland' 'Slovakia' 'Slovenia' 'Norway' 'Estonia' 'Hungary' 'Monaco'
#  'Lithuania' 'Belarus' 'Greece' 'Russia' 'Croatia' 'Turkey' 'Latvia'
#  'Romania' 'Bulgaria' 'Iceland' 'Liechtenstein']
# --------------------------------------------------
# Kolumna: Pierwszy_wlasciciel
# [nan 'Yes']
# --------------------------------------------------
# Kolumna: Data_pierwszej_rejestracji
# [nan '16/06/2010' '27/11/2007' ... '30/05/1989' '08/03/2009' '03/08/1992']
# --------------------------------------------------
# Kolumna: Data_publikacji_oferty
# ['28/04/2021' '04/05/2021' '03/05/2021' '02/05/2021' '24/04/2021'
#  '30/04/2021' nan '01/05/2021' '26/04/2021' '29/04/2021' '08/04/2021'
#  '25/04/2021' '27/04/2021' '19/04/2021' '21/04/2021' '22/04/2021'
#  '15/04/2021' '23/04/2021' '20/04/2021' '17/04/2021' '05/04/2021'
#  '05/05/2021' '16/04/2021' '13/04/2021' '02/04/2021' '27/03/2021'
#  '07/04/2021' '09/04/2021' '10/04/2021' '11/04/2021' '12/04/2021'
#  '18/04/2021' '04/04/2021' '06/04/2021' '14/04/2021' '31/03/2021'
#  '30/03/2021' '03/04/2021' '28/03/2021' '26/03/2021' '01/04/2021'
#  '29/03/2021']
# --------------------------------------------------
# Kolumna: Lokalizacja_oferty
# ['SŁONECZNA 1 - 99-300 Kutno, kutnowski, Łódzkie (Polska)'
#  'ul. Wiosenna 8 - 41-407 Imielin, Centrum (Polska)'
#  'Sianów, koszaliński, Zachodniopomorskie' ...
#  'Przemysłowa 1 - 38-200 Jasło, jasielski, Podkarpackie (Polska)'
#  'Łęczyca, stargardzki, Zachodniopomorskie'
#  'Parchów, polkowicki, Dolnośląskie']
# --------------------------------------------------
# Kolumna: Wyposazenie
# ["['ABS', 'Electric front windows', 'Drivers airbag', 'Power steering', 'USB socket', 'On-board computer', 'CD', 'Electrically adjustable mirrors', 'Passengers airbag', 'Alloy wheels', 'Isofix', 'Start-Stop system', 'Central locking', 'Immobilizer', 'Factory radio', 'Rain sensor', 'Dual zone air conditioning', 'Cruise control']"
#  "['ABS', 'Electric front windows', 'Drivers airbag', 'Power steering', 'Twilight sensor', 'Electrochromic rear view mirror', 'Isofix', 'Heated front seats', 'Velor upholstery', 'CD', 'Electrically adjustable mirrors', 'Passengers airbag', 'Alloy wheels', 'Rear parking sensors', 'Electric rear windows', 'Manual air conditioning', 'Roof rails', 'Cruise control', 'Central locking', 'Immobilizer', 'Factory radio', 'Rain sensor', 'Electrochromic side mirrors', 'ESP(stabilization of the track)', 'On-board computer', 'Fog lights', 'Multifunction steering wheel']"
#  "['ABS', 'Electric front windows', 'Passengers airbag', 'ASR (traction control)', 'Rear parking sensors', 'SD socket', 'Automatic air conditioning', 'Heated front seats', 'CD', 'Immobilizer', 'Factory radio', 'Bluetooth', 'ESP(stabilization of the track)', 'USB socket', 'On-board computer', 'Tinted windows', 'Central locking', 'Drivers airbag', 'Power steering', 'Rain sensor', 'AUX socket', 'Isofix', 'MP3', 'Start-Stop system']"
#  ...
#  "['ABS', 'Electric front windows', 'Drivers airbag', 'Power steering', 'ASR (traction control)', 'Rain sensor', 'Electrochromic rear view mirror', 'ESP(stabilization of the track)', 'Isofix', 'Dual zone air conditioning', 'Shift paddles', 'Heated windscreen', 'Airbag protecting the knees', 'Tinted windows', 'Sunroof', 'Xenon lights', 'Multifunction steering wheel', 'CD', 'Electrically adjustable mirrors', 'Passengers airbag', 'Alarm', 'Lane assistant', 'Twilight sensor', 'Electric rear windows', 'AUX socket', 'Rear view camera', 'On-board computer', 'MP3', 'Heated side mirrors', 'Front side airbags', 'Roof rails', 'Daytime running lights', 'Leather upholstery', 'Central locking', 'Immobilizer', 'Factory radio', 'Alloy wheels', 'Bluetooth', 'Rear parking sensors', 'Electrically adjustable seats', 'USB socket', 'Automatic air conditioning', 'Air curtains', 'GPS navigation', 'Heated front seats', 'Rear side airbags', 'Start-Stop system', 'Fog lights', 'Cruise control']"
#  "['ABS', 'Electric front windows', 'Drivers airbag', 'Power steering', 'ASR (traction control)', 'Bluetooth', 'Twilight sensor', 'Electrochromic rear view mirror', 'AUX socket', 'Isofix', 'Dual zone air conditioning', 'MP3', 'Heated side mirrors', 'Front side airbags', 'Roof rails', 'LED lights', 'Active cruise control', 'Shift paddles', 'CD', 'Electrically adjustable mirrors', 'Passengers airbag', 'Alarm', 'Parking assistant', 'Rain sensor', 'Front parking sensors', 'Electric rear windows', 'SD socket', 'Rear view camera', 'On-board computer', 'GPS navigation', 'Heated front seats', 'Rear side airbags', 'Start-Stop system', 'Fog lights', 'Multifunction steering wheel', 'Central locking', 'Immobilizer', 'Factory radio', 'Alloy wheels', 'Lane assistant', 'Blind spot sensor', 'Rear parking sensors', 'ESP(stabilization of the track)', 'USB socket', 'Automatic air conditioning', 'Air curtains', 'Speed limiter', 'Airbag protecting the knees', 'Tinted windows', 'Daytime running lights', 'Cruise control', 'HUD(head-up display)']"
#  "['ABS', 'Rain sensor', 'Electric front windows', 'Immobilizer', 'Roof rails', 'Fog lights', 'Power steering', 'Electrochromic rear view mirror', 'Rear side airbags', 'Drivers airbag', 'Hook', 'Automatic air conditioning', 'Alarm', 'Central locking', 'Electric rear windows', 'On-board computer', 'Tinted windows', 'Cruise control', 'Isofix', 'AUX socket', 'Air curtains', 'Front side airbags', 'Factory radio', 'Dual zone air conditioning', 'Alloy wheels', 'Electrically adjustable mirrors', 'Xenon lights', 'ASR (traction control)', 'Rear parking sensors', 'Multifunction steering wheel', 'Electrochromic side mirrors', 'ESP(stabilization of the track)', 'Passengers airbag', 'Daytime running lights', 'MP3']"]
# --------------------------------------------------
# Kolumna: is_train
# [1 0]
# --------------------------------------------------

# %%
record_number = len(full_dataset)
record_number_train = len(train_dataset)
record_number_test = len(test_dataset)

print(f"Liczba wszystkich rekordów: {record_number}")
print(f"Liczba rekordów w grupie treningowej: {record_number_train}")
print(f"Liczba rekordów w grupie testowej: {record_number_test}")
# Out:
# Liczba wszystkich rekordów: 208304
# Liczba rekordów w grupie treningowej: 135397
# Liczba rekordów w grupie testowej: 72907

# %%
# Liczenie brakujących wartości w każdej kolumnie
missing_values = full_dataset.isnull().sum()

# Wypisanie wyników
print(missing_values)
# Out:
# ID                                 0
# Cena                           72907
# Waluta                          3376
# Stan                            3322
# Marka_pojazdu                   3351
# Model_pojazdu                   3309
# Wersja_pojazdu                 72574
# Generacja_pojazdu              62833
# Rok_produkcji                   3407
# Przebieg_km                     4333
# Moc_KM                          3962
# Pojemnosc_cm3                   5372
# Rodzaj_paliwa                   3410
# Emisja_CO2                    115861
# Naped                          18186
# Skrzynia_biegow                 3938
# Typ_nadwozia                    3359
# Liczba_drzwi                    4902
# Kolor                           3463
# Kraj_pochodzenia               91902
# Pierwszy_wlasciciel           144260
# Data_pierwszej_rejestracji    123324
# Data_publikacji_oferty          3449
# Lokalizacja_oferty              3341
# Wyposazenie                     3253
# is_train                           0
# dtype: int64

# %% [markdown]
# ## Taking care of missing data

# %% [markdown]
# #### ID i Cena nie mają zadnych brakujących wartości, ale pozostałe zmienne mają

# %% [markdown]
# #### Stan

# %%
# Wypisanie unikalnych wartości

print(f"Kolumna: Stan")
print(full_dataset['Stan'].unique())

# Liczenie brakujących wartości
miss_val_Stan = full_dataset['Stan'].isnull().sum()
used_count = full_dataset['Stan'].value_counts().get("Used", 0)
new_count = full_dataset['Stan'].value_counts().get("New", 0)

print(f"Used: {used_count}")
print(f"New: {new_count}")
print(f"NaN: {miss_val_Stan}")
# Out:
# Kolumna: Stan
# ['Used' 'New' nan]
# Used: 179929
# New: 25053
# NaN: 3322

# %% [markdown]
# ##### Założenie: Jeśli samochód przejechał więcej niż 100 km, to zgodnie z definicją jest używany

# %%
# Iteracja po indeksach
for index in full_dataset.index:
    if pd.isna(full_dataset.loc[index, 'Stan']):  # Sprawdzenie, czy Stan to NaN
        przebieg = full_dataset.loc[index, 'Przebieg_km']
        # Upewnienie się, że Przebieg_km jest liczbą przed próbą konwersji
        if pd.notna(przebieg):  # Jeśli Przebieg_km nie jest NaN
            przebieg = int(przebieg)  # Konwersja na int
            # Sprawdzenie, czy Przebieg_km jest większy niż 100
            if przebieg > 100:
                full_dataset.loc[index, 'Stan'] = "Used"  # Ustawienie 'Stan' na 1

# %% [markdown]
# #### Zakodowanie wartości:
# #### Stan = 0 to nowy
# #### Stan = 1 uzywany

# %%
# Zamiana wartości "New" → 0, "Used" → 1, reszta jako NaN
full_dataset['Stan'] = full_dataset['Stan'].apply(lambda x: 0 if x == "New" else (1 if x == "Used" else np.nan))

# Zliczanie wartości
used_count = (full_dataset['Stan'] == 1).sum()
new_count = (full_dataset['Stan'] == 0).sum()
miss_val_Stan = full_dataset['Stan'].isna().sum()

# Wypisanie wyników
print(f"Used: {used_count}")
print(f"New: {new_count}")
print(f"NaN: {miss_val_Stan}")
# Out:
# Used: 182761
# New: 25053
# NaN: 490

# %% [markdown]
# #### Wynik: zmniejszenie liczby NaN w Stan z 3322 do 490

# %% [markdown]
# ### Marka_pojazdu

# %%
marki_count = full_dataset['Marka_pojazdu'].value_counts()
miss_val_marki = full_dataset['Marka_pojazdu'].isnull().sum()
print(marki_count)
print(f"NaN: {miss_val_marki}")
# Out:
# Volkswagen    18151
# BMW           16735
# Audi          16459
# Opel          16068
# Ford          15727
#               ...
# MAN               1
# NSU               1
# Santana           1
# Scion             1
# Talbot            1
# Name: Marka_pojazdu, Length: 108, dtype: int64
# NaN: 3351

# %% [markdown]
# ### Model_pojazdu

# %%
model_count = full_dataset['Model_pojazdu'].value_counts()
miss_val_model = full_dataset['Model_pojazdu'].isnull().sum()
print(model_count)
print(f"NaN: {miss_val_model}")
# Out:
# Astra        5218
# A4           4510
# Seria 3      4499
# Golf         4099
# Passat       3989
#              ...
# 3500            1
# Countach        1
# Cressida        1
# Interstar       1
# GTC4Lusso       1
# Name: Model_pojazdu, Length: 1201, dtype: int64
# NaN: 3309

# %% [markdown]
# #### Załozenie: Jeśli znany jest model, ale brakuje marki to mona uzupełnić markę na podstawie modelu

# %%
# Usuwamy wiersze, gdzie Marka oraz Model są NaN
filtered_dataset = full_dataset.dropna(subset=['Marka_pojazdu', 'Model_pojazdu'])

# Tworzymy mapę Model → Marka
model_to_marka = filtered_dataset.set_index('Model_pojazdu')['Marka_pojazdu'].to_dict()

print(model_to_marka)
# Out:
# {'Grand Espace': 'Renault', 'Megane': 'Renault', 'Zafira': 'Opel', 'Focus': 'Ford', 'Avensis': 'Toyota', 'X5': 'BMW', 'A6': 'Audi', 'Scenic': 'Renault', 'A4': 'Audi', 'Golf': 'Volkswagen', 'X5 M': 'BMW', 'A3': 'Audi', 'Tucson': 'Hyundai', 'Soul': 'Kia', 'Passat': 'Volkswagen', 'Qashqai': 'Nissan', 'Duster': 'Dacia', 'Yaris': 'Toyota', '6': 'Mazda', 'XC 40': 'Volvo', 'XC 60': 'Volvo', 'Chairman': 'Daewoo', 'Tipo': 'Fiat', 'Astra': 'Opel', 'XF': 'Jaguar', 'Octavia': 'Škoda', 'Master': 'Renault', 'Seria 1': 'BMW', 'Vectra': 'Opel', 'i40': 'Hyundai', 'Lancer': 'Mitsubishi', '308': 'Peugeot', 'Altea XL': 'Seat', 'X3': 'BMW', 'Ranger': 'Ford', 'Cayenne': 'Porsche', 'Fabia': 'Škoda', 'Sedici': 'Fiat', 'V50': 'Volvo', 'Jazz': 'Honda', 'Grand Cherokee': 'Jeep', 'Doblo': 'Fiat', 'Clio': 'Renault', 'C3': 'Citroën', 'Cherokee': 'Jeep', 'ASX': 'Mitsubishi', 'Sprinter': 'Mercedes-Benz', 'Blazer': 'Chevrolet', 'Ceed': 'Kia', '911': 'Porsche', 'Seria 5': 'BMW', 'Arteon': 'Volkswagen', 'Corsa': 'Opel', 'Insignia': 'Opel', 'Stonic': 'Kia', 'RAPID': 'Škoda', '508': 'Peugeot', 'XV': 'Subaru', 'ix20': 'Hyundai', 'Cooper S': 'MINI', 'Trafic': 'Renault', 'GL': 'Mercedes-Benz', 'Grande Punto': 'Fiat', 'Corolla': 'Toyota', 'Superb': 'Škoda', 'Lodgy': 'Dacia', 'Q5': 'Audi', 'CX-5': 'Mazda', 'A8': 'Audi', 'Ibiza': 'Seat', 'I30': 'Hyundai', 'Klasa E': 'Mercedes-Benz', 'Fusion': 'Ford', 'Logan': 'Dacia', 'Accord': 'Honda', 'Antara': 'Opel', 'Seria 3': 'BMW', '307': 'Peugeot', 'RAV4': 'Toyota', 'A5': 'Audi', 'Crossland X': 'Opel', 'Espace': 'Renault', 'S90': 'Volvo', '3': 'Mazda', 'Klasa C': 'Mercedes-Benz', 'Supra': 'Toyota', 'Aygo': 'Toyota', 'C5': 'Citroën', 'Transporter': 'Volkswagen', 'Caravelle': 'Volkswagen', 'Orlando': 'Chevrolet', 'Galaxy': 'Ford', 'Mondeo': 'Ford', 'S40': 'Volvo', 'C-HR': 'Toyota', 'S60': 'Volvo', '159': 'Alfa Romeo', 'Compass': 'Jeep', '3008': 'Peugeot', 'OUTBACK': 'Subaru', 'Auris': 'Toyota', 'Cordoba': 'Seat', 'Patrol': 'Nissan', 'Renegade': 'Jeep', 'Forfour': 'Smart', 'SX4 S-Cross': 'Suzuki', 'CLS': 'Mercedes-Benz', 'Seria 6': 'BMW', 'Sorento': 'Kia', 'Golf Plus': 'Volkswagen', 'Aveo': 'Chevrolet', 'Regal': 'Buick', 'Touareg': 'Volkswagen', 'up!': 'Volkswagen', '488': 'Ferrari', 'X1': 'BMW', 'Seria 2': 'BMW', '208': 'Peugeot', 'C4': 'Citroën', 'CR-V': 'Honda', 'Picanto': 'Kia', 'Altea': 'Seat', 'Cooper': 'MINI', 'Tiguan': 'Volkswagen', 'Fiesta': 'Ford', 'Mustang': 'Ford', 'Sportage': 'Kia', 'Xsara Picasso': 'Citroën', 'GT': 'Opel', 'Arona': 'Seat', 'Park Avenue': 'Buick', 'C-MAX': 'Ford', 'X-Trail': 'Nissan', 'Wrangler': 'Jeep', 'Vitara': 'Suzuki', '2008': 'Peugeot', 'S5': 'Audi', 'ZX': 'Citroën', 'Klasa S': 'Mercedes-Benz', 'Stelvio': 'Alfa Romeo', 'Meriva': 'Opel', 'Other': 'Maybach', 'DS4': 'Citroën', 'Captur': 'Renault', 'ix35': 'Hyundai', 'DS 5': 'DS Automobiles', 'S-Max': 'Ford', 'Mokka': 'Opel', 'X6 M': 'BMW', 'Puma': 'Ford', 'Seria 7': 'BMW', 'Adam': 'Opel', 'Leon': 'Seat', 'SQ5': 'Audi', 'GLE': 'Mercedes-Benz', 'Modus': 'Renault', 'C3 Aircross': 'Citroën', 'Countryman': 'MINI', '9-3': 'Saab', 'Scala': 'Škoda', 'C5 Aircross': 'Citroën', 'Santa Fe': 'Hyundai', 'Klasa B': 'Mercedes-Benz', 'Proace Verso': 'Toyota', 'Discovery': 'Land Rover', 'Q2': 'Audi', 'Seria 900': 'Volvo', 'ONE': 'MINI', 'Land Cruiser': 'Toyota', 'Vivaro': 'Opel', 'Laguna': 'Renault', 'Panda': 'Fiat', 'Clubman': 'MINI', 'Enyaq': 'Škoda', 'Delta': 'Lancia', '207': 'Peugeot', '500L': 'Fiat', 'Stinger': 'Kia', '5008': 'Peugeot', 'Verso S': 'Toyota', 'ProAce': 'Toyota', 'L200': 'Mitsubishi', 'Kadjar': 'Renault', 'Tigra': 'Opel', 'Q3': 'Audi', 'SL': 'Mercedes-Benz', 'Kamiq': 'Škoda', 'XCeed': 'Kia', 'Grand Vitara': 'Suzuki', 'Touran': 'Volkswagen', 'Punto': 'Fiat', 'Civic': 'Honda', 'ML': 'Mercedes-Benz', 'C30': 'Volvo', 'Gladiator': 'Jeep', 'Focus C-Max': 'Ford', 'Polo': 'Volkswagen', 'CLA': 'Mercedes-Benz', 'X6': 'BMW', 'GLC': 'Mercedes-Benz', 'Dokker': 'Dacia', 'Giulietta': 'Alfa Romeo', 'C4 Picasso': 'Citroën', 'Swift': 'Suzuki', 'Passat CC': 'Volkswa ...

# %%
# Uzupełnianie brakujących marek na podstawie mapy
full_dataset['Marka_pojazdu'] = full_dataset.apply(
    lambda row: model_to_marka[row['Model_pojazdu']] if pd.isna(row['Marka_pojazdu']) and row['Model_pojazdu'] in model_to_marka else row['Marka_pojazdu'],
    axis=1
)

# %%
miss_val_marki = full_dataset['Marka_pojazdu'].isnull().sum()
print(f"NaN: {miss_val_marki}")
# Out:
# NaN: 80

# %% [markdown]
# #### Wynik: zmniejszenie liczby NaN w Marka_pozadu z 3309 do 80

# %% [markdown]
# ## Inzynieria cech

# %% [markdown]
# ### Utworzymy zmienną Wiek_pojazdu na podstawie kolumn Rok_produkcji, Data_pierwszej_rejestracji oraz Data_publikacji_oferty pozywając się NaN

# %% [markdown]
# #### Wyciąganie roku z Data_pierwszej_rejestracji

# %%
# Konwersja kolumny na format datetime
full_dataset['Data_pierwszej_rejestracji'] = pd.to_datetime(full_dataset['Data_pierwszej_rejestracji'], format='%d/%m/%Y', errors='coerce')

# Wyodrębnienie roku rejestracji
full_dataset['Rok_rejestracji'] = full_dataset['Data_pierwszej_rejestracji'].dt.year

# Podgląd wyników
print(full_dataset[['Data_pierwszej_rejestracji', 'Rok_rejestracji']].head())
# Out:
#   Data_pierwszej_rejestracji  Rok_rejestracji
# 0                        NaT              NaN
# 1                 2010-06-16           2010.0
# 2                        NaT              NaN
# 3                 2007-11-27           2007.0
# 4                 2013-05-20           2013.0

# %% [markdown]
# #### Załozenie: W miejscu brakującego roku produkcji mozemy w przyblizeniu wstawic datę pierwszej rejestracji

# %%
# Sprawdzenie liczby brakujących wartości przed uzupełnieniem
print(f"Brakujące wartości w Rok_produkcji przed: {full_dataset['Rok_produkcji'].isna().sum()}")

# Uzupełnianie braków w Rok_produkcji danymi z Rok_rejestracji, jeśli są dostępne
full_dataset['Rok_produkcji'] = full_dataset.apply(
    lambda row: row['Rok_rejestracji'] if pd.isna(row['Rok_produkcji']) and not pd.isna(row['Rok_rejestracji']) else row['Rok_produkcji'], 
    axis=1
)

# Sprawdzenie, ile wartości udało się uzupełnić
print(f"Brakujące wartości w Rok_produkcji po: {full_dataset['Rok_produkcji'].isna().sum()}")
# Out:
# Brakujące wartości w Rok_produkcji przed: 3407
# Brakujące wartości w Rok_produkcji po: 2085

# %% [markdown]
# #### Załozenie: Dla danego modelu kazdej marki mozna ustalić średni rok produkcji

# %%
# Grupowanie po 'Marka_pojazdu' i 'Model_pojazdu' i obliczanie średniego roku produkcji
mean_rok_produkcji = full_dataset.groupby(['Marka_pojazdu', 'Model_pojazdu'])['Rok_produkcji'].mean().reset_index()

# Zaokrąglamy wartości do pełnych lat i konwertujemy na Int64
mean_rok_produkcji['Rok_produkcji'] = mean_rok_produkcji['Rok_produkcji'].round()

# %%
# Tworzymy słownik: Marka + Model -> Średni Rok
model_marka_to_mean_rok_produkcji = mean_rok_produkcji.set_index(['Marka_pojazdu', 'Model_pojazdu'])['Rok_produkcji'].to_dict()

# %%
# Uzupełnianie brakujących wartości w 'Rok_produkcji' na podstawie średniego roku produkcji dla danej marki i modelu
full_dataset['Rok_produkcji'] = full_dataset.apply(
    lambda row: model_marka_to_mean_rok_produkcji.get((row['Marka_pojazdu'], row['Model_pojazdu'])) 
    if pd.isna(row['Rok_produkcji']) else row['Rok_produkcji'], 
    axis=1
)

# %%
miss_val_rok_produkcji = full_dataset['Rok_produkcji'].isnull().sum()
print(f"NaN: {miss_val_rok_produkcji}")
# Out:
# NaN: 53

# %%
# Najstarszy rok produkcji
najstarszy_rok = full_dataset['Rok_produkcji'].min()

# Najnowszy rok produkcji
najnowszy_rok = full_dataset['Rok_produkcji'].max()

# Wyświetlenie wyników
print(f"Najstarszy rok produkcji: {najstarszy_rok}")
print(f"Najnowszy rok produkcji: {najnowszy_rok}")
# Out:
# Najstarszy rok produkcji: 1915.0
# Najnowszy rok produkcji: 2021.0

# %% [markdown]
# #### Wynik: zmniejszenie liczby NaN w Rok_produkcji z 3407 do 53

# %% [markdown]
# #### Wyciąganie roku z Data_publikacji_oferty

# %%
miss_val_data_publikacji = full_dataset['Data_publikacji_oferty'].isnull().sum()
print(f"NaN: {miss_val_data_publikacji}")
# Out:
# NaN: 3449

# %%
# Konwersja kolumny na format datetime
full_dataset['Data_publikacji_oferty'] = pd.to_datetime(full_dataset['Data_publikacji_oferty'], format='%d/%m/%Y', errors='coerce')

# Wyodrębnienie roku rejestracji
full_dataset['Rok_publikacji'] = full_dataset['Data_publikacji_oferty'].dt.year

# Podgląd wyników
print(full_dataset[['Data_publikacji_oferty', 'Rok_publikacji']].head())
# Out:
#   Data_publikacji_oferty  Rok_publikacji
# 0             2021-04-28          2021.0
# 1             2021-05-04          2021.0
# 2             2021-05-03          2021.0
# 3             2021-05-02          2021.0
# 4             2021-05-02          2021.0

# %%
# Najstarszy rok publikacji
najstarszy_rok_publikacji = full_dataset['Rok_publikacji'].min()

# Najnowszy rok publikacji
najnowszy_rok_publikacji = full_dataset['Rok_publikacji'].max()

# Wyświetlenie wyników
print(f"Najstarszy rok publikacji: {najstarszy_rok_publikacji}")
print(f"Najnowszy rok publikacji: {najnowszy_rok_publikacji}")
# Out:
# Najstarszy rok publikacji: 2021.0
# Najnowszy rok publikacji: 2021.0

# %% [markdown]
# #### Uwaga: Oferty są z jednego roku

# %% [markdown]
# ### Utworzymy zmienną Wiek_pojazdu

# %%
# Uzupełnianie brakujących wartości w Rok_publikacji na 2021
full_dataset['Rok_publikacji'] = full_dataset['Rok_publikacji'].fillna(2021)

# Obliczenie wieku samochodu: Rok_publikacji - Rok_produkcji
full_dataset['Wiek_pojazdu'] = full_dataset['Rok_publikacji'] - full_dataset['Rok_produkcji']

# Sprawdzenie wyników
print(full_dataset[['Marka_pojazdu', 'Model_pojazdu', 'Rok_produkcji', 'Rok_publikacji', 'Wiek_pojazdu']].head())
# Out:
#   Marka_pojazdu Model_pojazdu  Rok_produkcji  Rok_publikacji  Wiek_pojazdu
# 0       Renault  Grand Espace         2005.0          2021.0          16.0
# 1       Renault        Megane         2010.0          2021.0          11.0
# 2          Opel        Zafira         2015.0          2021.0           6.0
# 3          Ford         Focus         2007.0          2021.0          14.0
# 4        Toyota       Avensis         2013.0          2021.0           8.0

# %% [markdown]
# ### Przebieg_km

# %%
miss_val_przebieg = full_dataset['Przebieg_km'].isnull().sum()
print(f"NaN: {miss_val_przebieg}")
# Out:
# NaN: 4333

# %% [markdown]
# #### Załozenie: mozna uśrednić przebieg dla danego roku produkcji pojazdu

# %%
# Grupowanie po 'Marka_pojazdu', 'Model_pojazdu' i 'Rok_produkcji' i obliczanie średniego przebiegu
mean_przebieg = full_dataset.groupby(['Marka_pojazdu', 'Model_pojazdu', 'Rok_produkcji'])['Przebieg_km'].mean().reset_index()

# Zaokrąglamy wartości do pełnych kilometrów
mean_przebieg['Przebieg_km'] = mean_przebieg['Przebieg_km'].round()

# Tworzymy słownik: Marka + Model + Rok_produkcji -> Średni przebieg
model_marka_rok_to_mean_przebieg = mean_przebieg.set_index(['Marka_pojazdu', 'Model_pojazdu', 'Rok_produkcji'])['Przebieg_km'].to_dict()

# Uzupełnianie brakujących wartości w 'Przebieg_km' na podstawie średniego przebiegu dla danej marki, modelu i roku produkcji
full_dataset['Przebieg_km'] = full_dataset.apply(
    lambda row: model_marka_rok_to_mean_przebieg.get((row['Marka_pojazdu'], row['Model_pojazdu'], row['Rok_produkcji']))
    if pd.isna(row['Przebieg_km']) else row['Przebieg_km'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Marka_pojazdu', 'Model_pojazdu', 'Rok_produkcji', 'Przebieg_km']].head())
# Out:
#   Marka_pojazdu Model_pojazdu  Rok_produkcji  Przebieg_km
# 0       Renault  Grand Espace         2005.0     213000.0
# 1       Renault        Megane         2010.0     117089.0
# 2          Opel        Zafira         2015.0     115600.0
# 3          Ford         Focus         2007.0     218000.0
# 4        Toyota       Avensis         2013.0     174645.0

# %%
miss_val_przebieg = full_dataset['Przebieg_km'].isnull().sum()
print(f"NaN: {miss_val_przebieg}")
# Out:
# NaN: 114

# %% [markdown]
# #### Wynik: zmniejszenie liczby NaN w Przebieg z 4333 do 114

# %% [markdown]
# ## Ustalenie waluty

# %% [markdown]
# ### Waluta

# %%
waluta_count = full_dataset['Waluta'].value_counts()
miss_waluta = full_dataset['Waluta'].isnull().sum()
print(waluta_count)
print(f"NaN: {miss_waluta}")
# Out:
# PLN    204664
# EUR       264
# Name: Waluta, dtype: int64
# NaN: 3376

# %% [markdown]
# #### Zalozenie: dla kazdego modelu i roku produkcji ustalimy srednia cene i sprawdzimy, czy brakujące waluty to EUR czy PLN

# %% [markdown]
# #### Kurs średni Euro za rok 2021 ze strony NBP: 4,5674

# %%
# Kurs wymiany z EUR na PLN
kurs_wymiany = 4.5674

# %%
# Przeliczenie ceny, jeżeli waluta to EUR
full_dataset['Cena'] = full_dataset.apply(
    lambda row: row['Cena'] * kurs_wymiany if row['Waluta'] == 'EUR' else row['Cena'],
    axis=1
)

# %%
# Konwertowanie kolumny Cena na numeryczną (w razie potrzeby)
full_dataset['Cena'] = pd.to_numeric(full_dataset['Cena'], errors='coerce')

# Grupowanie po 'Model_pojazdu' i 'Rok_produkcji' i obliczanie średnich cen w PLN i EUR
mean_prices = full_dataset.groupby(['Model_pojazdu', 'Rok_produkcji', 'Waluta'])['Cena'].mean().reset_index()

# Ustawienie średnich cen w PLN i EUR w osobnych kolumnach
mean_prices_pln = mean_prices[mean_prices['Waluta'] == 'PLN'][['Model_pojazdu', 'Rok_produkcji', 'Cena']].rename(columns={'Cena': 'Mean_Price_PLN'})
mean_prices_eur = mean_prices[mean_prices['Waluta'] == 'EUR'][['Model_pojazdu', 'Rok_produkcji', 'Cena']].rename(columns={'Cena': 'Mean_Price_EUR'})

# Łączenie średnich cen w PLN i EUR z głównym datasetem
full_dataset = full_dataset.merge(mean_prices_pln, on=['Model_pojazdu', 'Rok_produkcji'], how='left')
full_dataset = full_dataset.merge(mean_prices_eur, on=['Model_pojazdu', 'Rok_produkcji'], how='left')

# Uzupełnianie brakujących wartości w 'Waluta' na podstawie średnich cen i porównania z 'Cena'
full_dataset['Waluta'] = full_dataset.apply(
    lambda row: 'PLN' if pd.isna(row['Waluta']) and 
               (abs(row['Cena'] - row['Mean_Price_PLN']) < abs(row['Cena'] - row['Mean_Price_EUR'])) 
               else 
               ('EUR' if pd.isna(row['Waluta']) else row['Waluta']),
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Model_pojazdu', 'Rok_produkcji', 'Cena', 'Waluta', 'Mean_Price_PLN', 'Mean_Price_EUR']].head())
# Out:
#   Model_pojazdu  Rok_produkcji     Cena Waluta  Mean_Price_PLN  Mean_Price_EUR
# 0  Grand Espace         2005.0  13900.0    PLN    10299.750000             NaN
# 1        Megane         2010.0  25900.0    PLN    19737.512821             NaN
# 2        Zafira         2015.0  35900.0    PLN    42233.088235             NaN
# 3         Focus         2007.0   5999.0    PLN    10209.651685             NaN
# 4       Avensis         2013.0  44800.0    PLN    39594.416667             NaN

# %%
miss_waluta = full_dataset['Waluta'].isnull().sum()
print(f"NaN: {miss_waluta}")
# Out:
# NaN: 0

# %% [markdown]
# #### Wynik: Zmniejszenie liczby NaN w Waluta z 3376 do 0

# %% [markdown]
# #### Załozenie: Moc silnika zalezy od rodzaju paliwa i danego modelu

# %%
miss_moc = full_dataset['Moc_KM'].isnull().sum()
print(f"NaN: {miss_moc}")
# Out:
# NaN: 3962

# %%
# Grupowanie po 'Model_pojazdu' i 'Rodzaj_paliwa' i obliczanie średniej mocy
mean_moc = full_dataset.groupby(['Model_pojazdu', 'Rodzaj_paliwa'])['Moc_KM'].mean().reset_index()

# Zaokrąglamy wartości do pełnych KM
mean_moc['Moc_KM'] = mean_moc['Moc_KM'].round()

# Tworzymy słownik: Model + Rodzaj_paliwa -> Średnia moc
model_paliwo_to_mean_moc = mean_moc.set_index(['Model_pojazdu', 'Rodzaj_paliwa'])['Moc_KM'].to_dict()

# Uzupełnianie brakujących wartości w 'Moc' na podstawie średniego przebiegu dla danej marki, modelu i roku produkcji
full_dataset['Moc_KM'] = full_dataset.apply(
    lambda row: model_paliwo_to_mean_moc.get((row['Model_pojazdu'], row['Rodzaj_paliwa']))
    if pd.isna(row['Moc_KM']) else row['Moc_KM'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Marka_pojazdu', 'Model_pojazdu', 'Moc_KM', 'Rodzaj_paliwa']].head())
# Out:
#   Marka_pojazdu Model_pojazdu  Moc_KM Rodzaj_paliwa
# 0       Renault  Grand Espace   170.0      Gasoline
# 1       Renault        Megane   110.0      Gasoline
# 2          Opel        Zafira   136.0           NaN
# 3          Ford         Focus    90.0        Diesel
# 4        Toyota       Avensis   142.0      Gasoline

# %%
miss_moc = full_dataset['Moc_KM'].isnull().sum()
print(f"NaN: {miss_moc}")
# Out:
# NaN: 194

# %% [markdown]
# #### Wynik: zmniejszenie NaN w Moc silnika z 3962 do 194

# %% [markdown]
# #### Załozenie: Pojemność silnika zalezy od mocy silnika i danego modelu

# %%
miss_pojemnosc = full_dataset['Pojemnosc_cm3'].isnull().sum()
print(f"NaN: {miss_pojemnosc}")

# Grupowanie po 'Model_pojazdu' i 'Moc_KM' i obliczanie średniej mocy
mean_moc = full_dataset.groupby(['Model_pojazdu', 'Moc_KM'])['Pojemnosc_cm3'].mean().reset_index()

# Zaokrąglamy wartości do pełnych KM
mean_moc['Pojemnosc_cm3'] = mean_moc['Pojemnosc_cm3'].round()

# Tworzymy słownik: Model + Moc_KM -> Średnia pojemnosc
model_paliwo_to_mean_moc = mean_moc.set_index(['Model_pojazdu', 'Moc_KM'])['Pojemnosc_cm3'].to_dict()

# Uzupełnianie brakujących wartości w Pojemnosc na podstawie średniego przebiegu dla modelu i mocy silnika
full_dataset['Pojemnosc_cm3'] = full_dataset.apply(
    lambda row: model_paliwo_to_mean_moc.get((row['Model_pojazdu'], row['Moc_KM']))
    if pd.isna(row['Pojemnosc_cm3']) else row['Pojemnosc_cm3'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Marka_pojazdu', 'Model_pojazdu', 'Pojemnosc_cm3', 'Moc_KM']].head())

miss_pojemnosc = full_dataset['Pojemnosc_cm3'].isnull().sum()
print(f"NaN: {miss_pojemnosc}")
# Out:
# NaN: 5372
#   Marka_pojazdu Model_pojazdu  Pojemnosc_cm3  Moc_KM
# 0       Renault  Grand Espace         1998.0   170.0
# 1       Renault        Megane         1598.0   110.0
# 2          Opel        Zafira         1598.0   136.0
# 3          Ford         Focus         1560.0    90.0
# 4        Toyota       Avensis         1798.0   142.0
# NaN: 1292

# %% [markdown]
# #### Wynik: zmniejszenie NaN w Pojemność silnika z 5372 do 1292

# %% [markdown]
# #### Załozenie: Rodzaj_paliwa zalezy od modelu i mocy

# %%
paliwo_count = full_dataset['Rodzaj_paliwa'].value_counts()
miss_paliwo = full_dataset['Rodzaj_paliwa'].isnull().sum()
print(paliwo_count)
print(f"NaN: {miss_paliwo}")
# Out:
# Gasoline          97773
# Diesel            90851
# Gasoline + LPG     8882
# Hybrid             5792
# Electric           1523
# Gasoline + CNG       69
# Hydrogen              2
# Ethanol               2
# Name: Rodzaj_paliwa, dtype: int64
# NaN: 3410

# %%
# Sprawdzenie brakujących danych w kolumnie 'Rodzaj_paliwa'
miss_paliwo = full_dataset['Rodzaj_paliwa'].isnull().sum()
print(f"NaN: {miss_paliwo}")

# Grupowanie po 'Model_pojazdu' i 'Moc_KM' i obliczanie najczęstszego rodzaju paliwa
mode_paliwo = full_dataset.groupby(['Model_pojazdu', 'Moc_KM'])['Rodzaj_paliwa'].agg(lambda x: x.mode()[0] if not x.mode().empty else None).reset_index()

# Tworzymy słownik: Model + Moc_KM -> Najczęstszy rodzaj paliwa
model_moc_to_paliwo = mode_paliwo.set_index(['Model_pojazdu', 'Moc_KM'])['Rodzaj_paliwa'].to_dict()

# Uzupełnianie brakujących wartości w 'Rodzaj_paliwa' na podstawie najczęstszego paliwa dla modelu i mocy
full_dataset['Rodzaj_paliwa'] = full_dataset.apply(
    lambda row: model_moc_to_paliwo.get((row['Model_pojazdu'], row['Moc_KM']))
    if pd.isna(row['Rodzaj_paliwa']) else row['Rodzaj_paliwa'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Marka_pojazdu', 'Model_pojazdu', 'Rodzaj_paliwa', 'Moc_KM']].head())

# Sprawdzanie brakujących wartości po uzupełnieniu
miss_paliwo = full_dataset['Rodzaj_paliwa'].isnull().sum()
print(f"NaN: {miss_paliwo}")
# Out:
# NaN: 3410
#   Marka_pojazdu Model_pojazdu Rodzaj_paliwa  Moc_KM
# 0       Renault  Grand Espace      Gasoline   170.0
# 1       Renault        Megane      Gasoline   110.0
# 2          Opel        Zafira        Diesel   136.0
# 3          Ford         Focus        Diesel    90.0
# 4        Toyota       Avensis      Gasoline   142.0
# NaN: 250

# %% [markdown]
# #### Wynik: zmniejszenie NaN w Rodzaj_paliwa z 3410 do 250

# %% [markdown]
# #### Załozenie: Emisja_CO2 zalezy od Rodzaju paliwa, Pojemności silnika

# %%
# Liczba brakujących wartości w Emisja_CO2
miss_emisja = full_dataset['Emisja_CO2'].isnull().sum()
print(f"NaN przed uzupełnieniem: {miss_emisja}")

# Grupowanie po 'Rodzaj_paliwa' i 'Moc_KM' i obliczanie średniej emisji CO2
mean_emisja = full_dataset.groupby(['Rodzaj_paliwa', 'Moc_KM'])['Emisja_CO2'].mean().reset_index()

# Zaokrąglamy wartości emisji CO2
mean_emisja['Emisja_CO2'] = mean_emisja['Emisja_CO2'].round()

# Tworzymy słownik: (Rodzaj_paliwa, Moc_KM) -> Średnia emisja CO2
paliwo_moc_to_mean_emisja = mean_emisja.set_index(['Rodzaj_paliwa', 'Moc_KM'])['Emisja_CO2'].to_dict()

# Uzupełnianie brakujących wartości w Emisja_CO2 na podstawie średniej emisji dla danego paliwa i mocy silnika
full_dataset['Emisja_CO2'] = full_dataset.apply(
    lambda row: paliwo_moc_to_mean_emisja.get((row['Rodzaj_paliwa'], row['Moc_KM']))
    if pd.isna(row['Emisja_CO2']) else row['Emisja_CO2'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Marka_pojazdu', 'Model_pojazdu', 'Emisja_CO2', 'Moc_KM']].head())

# Liczba brakujących wartości po uzupełnieniu
miss_emisja = full_dataset['Emisja_CO2'].isnull().sum()
print(f"NaN po uzupełnieniu: {miss_emisja}")
# Out:
# NaN przed uzupełnieniem: 115861
#   Marka_pojazdu Model_pojazdu  Emisja_CO2  Moc_KM
# 0       Renault  Grand Espace       232.0   170.0
# 1       Renault        Megane       159.0   110.0
# 2          Opel        Zafira       145.0   136.0
# 3          Ford         Focus       118.0    90.0
# 4        Toyota       Avensis       152.0   142.0
# NaN po uzupełnieniu: 2655

# %% [markdown]
# #### Wynik: zmniejszenie NaN w Emisja_CO2 z 115861 do 2665

# %% [markdown]
# #### Załozenie: Typ_nadwozia zalezy od modelu

# %%
miss_nadwozie = full_dataset['Typ_nadwozia'].isnull().sum()
print(f"NaN: {miss_nadwozie}")

# Grupowanie po 'Model_pojazdu' obliczanie najczęstszego typu nadwozia
mode_paliwo = full_dataset.groupby(['Model_pojazdu'])['Typ_nadwozia'].agg(lambda x: x.mode()[0] if not x.mode().empty else None).reset_index()

# Tworzymy słownik
model_moc_to_paliwo = mode_paliwo.set_index(['Model_pojazdu'])['Typ_nadwozia'].to_dict()

# Uzupełnianie brakujących wartości
full_dataset['Typ_nadwozia'] = full_dataset.apply(
    lambda row: model_moc_to_paliwo.get((row['Model_pojazdu']))
    if pd.isna(row['Typ_nadwozia']) else row['Typ_nadwozia'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Model_pojazdu', 'Typ_nadwozia']].head())

# Sprawdzanie brakujących wartości po uzupełnieniu
miss_nadwozie = full_dataset['Typ_nadwozia'].isnull().sum()
print(f"NaN: {miss_nadwozie}")
# Out:
# NaN: 3359
#   Model_pojazdu   Typ_nadwozia
# 0  Grand Espace        minivan
# 1        Megane  station_wagon
# 2        Zafira        minivan
# 3         Focus        compact
# 4       Avensis  station_wagon
# NaN: 67

# %% [markdown]
# #### Wynik: zmniejszenie NaN w Typ_nadwozia z 3359 do 67

# %% [markdown]
# #### Załozenie: Liczba_drzwi zalezy od Typu nadwozia i Modelu

# %%
# Sprawdzenie brakujących danych
miss_drzwi = full_dataset['Liczba_drzwi'].isnull().sum()
print(f"NaN: {miss_drzwi}")

# Grupowanie
mode_paliwo = full_dataset.groupby(['Model_pojazdu', 'Typ_nadwozia'])['Liczba_drzwi'].agg(lambda x: x.mode()[0] if not x.mode().empty else None).reset_index()

# Tworzymy słownik
model_moc_to_paliwo = mode_paliwo.set_index(['Model_pojazdu', 'Typ_nadwozia'])['Liczba_drzwi'].to_dict()

# Uzupełnianie brakujących wartości
full_dataset['Liczba_drzwi'] = full_dataset.apply(
    lambda row: model_moc_to_paliwo.get((row['Model_pojazdu'], row['Typ_nadwozia']))
    if pd.isna(row['Liczba_drzwi']) else row['Liczba_drzwi'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Model_pojazdu', 'Typ_nadwozia', 'Liczba_drzwi']].head())

# Sprawdzenie brakujących danych
miss_drzwi = full_dataset['Liczba_drzwi'].isnull().sum()
print(f"NaN: {miss_drzwi}")
# Out:
# NaN: 4902
#   Model_pojazdu   Typ_nadwozia  Liczba_drzwi
# 0  Grand Espace        minivan           5.0
# 1        Megane  station_wagon           5.0
# 2        Zafira        minivan           5.0
# 3         Focus        compact           5.0
# 4       Avensis  station_wagon           4.0
# NaN: 147

# %% [markdown]
# #### Wynik: zmniejszenie NaN w Typ_nadwozia z 4902 do 147

# %% [markdown]
# #### Zalozenie: Naped zalezy od modelu

# %%
miss_nadwozie = full_dataset['Naped'].isnull().sum()
print(f"NaN: {miss_nadwozie}")

# Grupowanie po 'Model_pojazdu' obliczanie najczęstszego typu nadwozia
mode_paliwo = full_dataset.groupby(['Model_pojazdu'])['Naped'].agg(lambda x: x.mode()[0] if not x.mode().empty else None).reset_index()

# Tworzymy słownik
model_moc_to_paliwo = mode_paliwo.set_index(['Model_pojazdu'])['Naped'].to_dict()

# Uzupełnianie brakujących wartości
full_dataset['Naped'] = full_dataset.apply(
    lambda row: model_moc_to_paliwo.get((row['Model_pojazdu']))
    if pd.isna(row['Naped']) else row['Naped'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Model_pojazdu', 'Naped']].head())

# Sprawdzanie brakujących wartości po uzupełnieniu
miss_nadwozie = full_dataset['Naped'].isnull().sum()
print(f"NaN: {miss_nadwozie}")
# Out:
# NaN: 18186
#   Model_pojazdu         Naped
# 0  Grand Espace  Front wheels
# 1        Megane  Front wheels
# 2        Zafira  Front wheels
# 3         Focus  Front wheels
# 4       Avensis  Front wheels
# NaN: 411

# %%
miss_nadwozie = full_dataset['Skrzynia_biegow'].isnull().sum()
print(f"NaN: {miss_nadwozie}")

# Grupowanie po 'Model_pojazdu' obliczanie najczęstszego typu nadwozia
mode_paliwo = full_dataset.groupby(['Model_pojazdu'])['Skrzynia_biegow'].agg(lambda x: x.mode()[0] if not x.mode().empty else None).reset_index()

# Tworzymy słownik
model_moc_to_paliwo = mode_paliwo.set_index(['Model_pojazdu'])['Skrzynia_biegow'].to_dict()

# Uzupełnianie brakujących wartości
full_dataset['Skrzynia_biegow'] = full_dataset.apply(
    lambda row: model_moc_to_paliwo.get((row['Model_pojazdu']))
    if pd.isna(row['Skrzynia_biegow']) else row['Skrzynia_biegow'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Model_pojazdu', 'Skrzynia_biegow']].head())

# Sprawdzanie brakujących wartości po uzupełnieniu
miss_nadwozie = full_dataset['Skrzynia_biegow'].isnull().sum()
print(f"NaN: {miss_nadwozie}")
# Out:
# NaN: 3938
#   Model_pojazdu Skrzynia_biegow
# 0  Grand Espace          Manual
# 1        Megane          Manual
# 2        Zafira          Manual
# 3         Focus          Manual
# 4       Avensis          Manual
# NaN: 90

# %%
miss_kolor = full_dataset['Kolor'].isnull().sum()
print(f"NaN: {miss_kolor}")

# Uzupełnianie brakujących wartości
full_dataset['Kolor'] = full_dataset.apply(
    lambda row: "other" if pd.isna(row['Kolor']) else row['Kolor'], 
    axis=1
)

# Sprawdzenie wyników
print(full_dataset[['Model_pojazdu', 'Kolor']].head())

# Sprawdzanie brakujących wartości po uzupełnieniu
miss_kolor = full_dataset['Kolor'].isnull().sum()
print(f"NaN: {miss_kolor}")
# Out:
# NaN: 3463
#   Model_pojazdu   Kolor
# 0  Grand Espace    blue
# 1        Megane  silver
# 2        Zafira   white
# 3         Focus    blue
# 4       Avensis   other
# NaN: 0

# %% [markdown]
# ## Zmiana typu danych

# %% [markdown]
# ### Odrzucanie kolumn wyłączonych z modelu

# %%
for column in full_dataset:
    print(column)
# Out:
# ID
# Cena
# Waluta
# Stan
# Marka_pojazdu
# Model_pojazdu
# Wersja_pojazdu
# Generacja_pojazdu
# Rok_produkcji
# Przebieg_km
# Moc_KM
# Pojemnosc_cm3
# Rodzaj_paliwa
# Emisja_CO2
# Naped
# Skrzynia_biegow
# Typ_nadwozia
# Liczba_drzwi
# Kolor
# Kraj_pochodzenia
# Pierwszy_wlasciciel
# Data_pierwszej_rejestracji
# Data_publikacji_oferty
# Lokalizacja_oferty
# Wyposazenie
# is_train
# Rok_rejestracji
# Rok_publikacji
# Wiek_pojazdu
# Mean_Price_PLN
# Mean_Price_EUR

# %% [markdown]
# # # #

# %%
kolumny_do_usuniecia = ['Wersja_pojazdu', 'Generacja_pojazdu', 'Kraj_pochodzenia', 'Pierwszy_wlasciciel', 'Data_pierwszej_rejestracji', 'Data_publikacji_oferty', 'Lokalizacja_oferty', 'Rok_rejestracji', 'Wyposazenie', 'Mean_Price_PLN', 'Mean_Price_EUR']  # Wpisz nazwy kolumn do usunięcia
full_dataset_drop = full_dataset.drop(columns=kolumny_do_usuniecia)

# %%
# Sprawdzanie typu danych w każdej kolumnie
print(full_dataset_drop.dtypes)
# Out:
# ID                   int64
# Cena               float64
# Waluta              object
# Stan               float64
# Marka_pojazdu       object
# Model_pojazdu       object
# Rok_produkcji      float64
# Przebieg_km        float64
# Moc_KM             float64
# Pojemnosc_cm3      float64
# Rodzaj_paliwa       object
# Emisja_CO2         float64
# Naped               object
# Skrzynia_biegow     object
# Typ_nadwozia        object
# Liczba_drzwi       float64
# Kolor               object
# is_train             int64
# Rok_publikacji     float64
# Wiek_pojazdu       float64
# dtype: object

# %%
# Liczenie brakujących wartości w każdej kolumnie
missing_values = full_dataset_drop.isnull().sum()

# Wypisanie wyników
print(missing_values)
# Out:
# ID                     0
# Cena               72907
# Waluta                 0
# Stan                 490
# Marka_pojazdu         80
# Model_pojazdu       3309
# Rok_produkcji         53
# Przebieg_km          114
# Moc_KM               194
# Pojemnosc_cm3       1292
# Rodzaj_paliwa        250
# Emisja_CO2          2655
# Naped                411
# Skrzynia_biegow       90
# Typ_nadwozia          67
# Liczba_drzwi         147
# Kolor                  0
# is_train               0
# Rok_publikacji         0
# Wiek_pojazdu          53
# dtype: int64

# %% [markdown]
# ### Usunięcie rekordów z NaN pozostałych pomimo imputowania

# %%
# Sprawdzanie liczby wierszy przed usunięciem
before_drop = len(full_dataset_drop)

# Usunięcie wszystkich wierszy, które zawierają przynajmniej jeden NaN za wyjątkiem Cena (wszystkie ceny są puste test_dataset)
full_dataset_drop = full_dataset_drop.dropna(subset=[col for col in full_dataset_drop.columns if col != 'Cena'])

# Sprawdzanie liczby wierszy po usunięciu
after_drop = len(full_dataset_drop)

# Obliczanie liczby usuniętych wierszy
removed_rows = before_drop - after_drop

# Wyświetlanie wyniku
print(f"Liczba wierszy przed usunięciem: {before_drop}")
print(f"Liczba usuniętych wierszy: {removed_rows}")
print(f"Liczba wierszy po usunięciu: {after_drop}")

# %%
from sklearn.impute import SimpleImputer

# Sprawdzanie liczby wierszy przed wypełnieniem NaN
before_imputation = len(full_dataset_drop)

# Kolumny numeryczne (wykluczając 'Cena')
numeric_columns = [col for col in full_dataset_drop.columns if full_dataset_drop[col].dtype in ['float64', 'int64'] and col != 'Cena']

# Kolumny kategoryczne
categorical_columns = [col for col in full_dataset_drop.columns if full_dataset_drop[col].dtype == 'object' and col != 'Cena']

# Tworzenie SimpleImputer dla danych numerycznych (średnia)
numeric_imputer = SimpleImputer(strategy='mean')

# Tworzenie SimpleImputer dla danych kategorycznych (najczęstsza wartość)
categorical_imputer = SimpleImputer(strategy='most_frequent')

# Wypełnianie brakujących wartości w kolumnach numerycznych
full_dataset_drop[numeric_columns] = numeric_imputer.fit_transform(full_dataset_drop[numeric_columns])

# Wypełnianie brakujących wartości w kolumnach kategorycznych
full_dataset_drop[categorical_columns] = categorical_imputer.fit_transform(full_dataset_drop[categorical_columns])

# Sprawdzanie liczby wierszy po wypełnieniu NaN
after_imputation = len(full_dataset_drop)

# Obliczanie liczby wierszy, które zostały zmodyfikowane
removed_rows = before_imputation - after_imputation

# Wyświetlanie wyniku
print(f"Liczba wierszy przed wypełnieniem NaN: {before_imputation}")
print(f"Liczba wierszy po wypełnieniu NaN: {after_imputation}")
# Out:
# Liczba wierszy przed wypełnieniem NaN: 208304
# Liczba wierszy po wypełnieniu NaN: 208304

# %% [markdown]
# ### Kodowanie danych kategorialnych

# %%
categorical_features = full_dataset_drop.select_dtypes(include=['object']).columns
print("Kolumny kategorialne:", categorical_features.tolist())
# Out:
# Kolumny kategorialne: ['Waluta', 'Marka_pojazdu', 'Model_pojazdu', 'Rodzaj_paliwa', 'Naped', 'Skrzynia_biegow', 'Typ_nadwozia', 'Kolor']

# %% [markdown]
# #### Nie wiem dlaczego nie działą tu OneHotEncoder, zamiast tego get_dummies

# %%
print(full_dataset_drop.shape)

# Wykorzystanie pandas.get_dummies() do zakodowania zmiennych kategorialnych
full_dataset_transformed = pd.get_dummies(full_dataset_drop, columns=categorical_features, drop_first=True)

# Wynik
print(full_dataset_transformed.shape)
# Out:
# (208304, 20)
# (208304, 1353)

# %%
for column in full_dataset_transformed:
    print(column)
# Out:
# ID
# Cena
# Stan
# Rok_produkcji
# Przebieg_km
# Moc_KM
# Pojemnosc_cm3
# Emisja_CO2
# Liczba_drzwi
# is_train
# Rok_publikacji
# Wiek_pojazdu
# Waluta_PLN
# Marka_pojazdu_Acura
# Marka_pojazdu_Aixam
# Marka_pojazdu_Alfa Romeo
# Marka_pojazdu_Alpine
# Marka_pojazdu_Aston Martin
# Marka_pojazdu_Audi
# Marka_pojazdu_Austin
# Marka_pojazdu_Autobianchi
# Marka_pojazdu_BMW
# Marka_pojazdu_Baic
# Marka_pojazdu_Bentley
# Marka_pojazdu_Buick
# Marka_pojazdu_Cadillac
# Marka_pojazdu_Casalini
# Marka_pojazdu_Chatenet
# Marka_pojazdu_Chevrolet
# Marka_pojazdu_Chrysler
# Marka_pojazdu_Citroën
# Marka_pojazdu_Cupra
# Marka_pojazdu_DFSK
# Marka_pojazdu_DKW
# Marka_pojazdu_DS Automobiles
# Marka_pojazdu_Dacia
# Marka_pojazdu_Daewoo
# Marka_pojazdu_Daihatsu
# Marka_pojazdu_Dodge
# Marka_pojazdu_FAW
# Marka_pojazdu_Ferrari
# Marka_pojazdu_Fiat
# Marka_pojazdu_Ford
# Marka_pojazdu_GMC
# Marka_pojazdu_Gaz
# Marka_pojazdu_Grecav
# Marka_pojazdu_Honda
# Marka_pojazdu_Hummer
# Marka_pojazdu_Hyundai
# Marka_pojazdu_Infiniti
# Marka_pojazdu_Inny
# Marka_pojazdu_Isuzu
# Marka_pojazdu_Iveco
# Marka_pojazdu_Jaguar
# Marka_pojazdu_Jeep
# Marka_pojazdu_Kia
# Marka_pojazdu_Lada
# Marka_pojazdu_Lamborghini
# Marka_pojazdu_Lancia
# Marka_pojazdu_Land Rover
# Marka_pojazdu_Lexus
# Marka_pojazdu_Ligier
# Marka_pojazdu_Lincoln
# Marka_pojazdu_Lotus
# Marka_pojazdu_MAN
# Marka_pojazdu_MG
# Marka_pojazdu_MINI
# Marka_pojazdu_Maserati
# Marka_pojazdu_Maybach
# Marka_pojazdu_Mazda
# Marka_pojazdu_McLaren
# Marka_pojazdu_Mercedes-Benz
# Marka_pojazdu_Mercury
# Marka_pojazdu_Microcar
# Marka_pojazdu_Mitsubishi
# Marka_pojazdu_Moskwicz
# Marka_pojazdu_NSU
# Marka_pojazdu_Nissan
# Marka_pojazdu_Nysa
# Marka_pojazdu_Oldsmobile
# Marka_pojazdu_Opel
# Marka_pojazdu_Peugeot
# Marka_pojazdu_Plymouth
# Marka_pojazdu_Polonez
# Marka_pojazdu_Pontiac
# Marka_pojazdu_Porsche
# Marka_pojazdu_RAM
# Marka_pojazdu_Renault
# Marka_pojazdu_Rolls-Royce
# Marka_pojazdu_Rover
# Marka_pojazdu_Saab
# Marka_pojazdu_Santana
# Marka_pojazdu_Saturn
# Marka_pojazdu_Scion
# Marka_pojazdu_Seat
# Marka_pojazdu_Smart
# Marka_pojazdu_SsangYong
# Marka_pojazdu_Subaru
# Marka_pojazdu_Suzuki
# Marka_pojazdu_Syrena
# Marka_pojazdu_Talbot
# Marka_pojazdu_Tarpan
# Marka_pojazdu_Tata
# Marka_pojazdu_Tavria
# Marka_pojazdu_Tesla
# Marka_pojazdu_Toyota
# Marka_pojazdu_Trabant
# Marka_pojazdu_Triumph
# Marka_pojazdu_Uaz
# Marka_pojazdu_Vanderhall
# Marka_pojazdu_Vauxhall
# Marka_pojazdu_Volkswagen
# Marka_pojazdu_Volvo
# Marka_pojazdu_Warszawa
# Marka_pojazdu_Wartburg
# Marka_pojazdu_Wołga
# Marka_pojazdu_Zaporożec
# Marka_pojazdu_Zastava
# Marka_pojazdu_Škoda
# Marka_pojazdu_Żuk
# Model_pojazdu_1.5
# Model_pojazdu_1.6
# Model_pojazdu_10
# Model_pojazdu_100
# Model_pojazdu_100 NX
# Model_pojazdu_1000
# Model_pojazdu_1007
# Model_pojazdu_104
# Model_pojazdu_105
# Model_pojazdu_106
# Model_pojazdu_107
# Model_pojazdu_108
# Model_pojazdu_1100
# Model_pojazdu_1117
# Model_pojazdu_1118
# Model_pojazdu_121
# Model_pojazdu_124
# Model_pojazdu_124 Spider
# Model_pojazdu_125p
# Model_pojazdu_126
# Model_pojazdu_127
# Model_pojazdu_128
# Model_pojazdu_130
# Model_pojazdu_1300
# Model_pojazdu_131
# Model_pojazdu_145
# Model_pojazdu_146
# Model_pojazdu_147
# Model_pojazdu_1500
# Model_pojazdu_155
# Model_pojazdu_156
# Model_pojazdu_159
# Model_pojazdu_164
# Model_pojazdu_166
# Model_pojazdu_18
# Model_pojazdu_19
# Model_pojazdu_1M
# Model_pojazdu_2
# Model_pojazdu_2 CV
# Model_pojazdu_200
# Model_pojazdu_200 SX
# Model_pojazdu_2008
# Model_pojazdu_203
# Model_pojazdu_204
# Model_pojazdu_205
# Model_pojazdu_206
# Model_pojazdu_206 CC
# Model_pojazdu_206 plus
# Model_pojazdu_207
# Model_pojazdu_207 CC
# Model_pojazdu_208
# Model_pojazdu_2101
# Model_pojazdu_2108
# Model_pojazdu_214
# Model_pojazdu_2141
# Model_pojazdu_220
# Model_pojazdu_224
# Model_pojazdu_233
# Model_pojazdu_237
# Model_pojazdu_2410
# Model_pojazdu_25
# Model_pojazdu_262
# Model_pojazdu_280
# Model_pojazdu_280 ZX
# Model_pojazdu_3
# Model_pojazdu_300
# Model_pojazdu_300 ZX
# Model_pojazdu_3000GT
# Model_pojazdu_3008
# Model_pojazdu_300C
# Model_pojazdu_300M
# Model_pojazdu_300s
# Model_pojazdu_301
# Model_pojazdu_304
# Model_pojazdu_306
# Model_pojazdu_307
# Model_pojazdu_307 CC
# Model_pojazdu_308
# Model_pojazdu_308 CC
# Model_pojazdu_311.0
# Model_pojazdu_3200
# Model_pojazdu_323
# Model_pojazdu_323F
# Model_pojazdu_340
# Model_pojazdu_348
# Model_pojazdu_350 Z
# Model_pojazdu_3500
# Model_pojazdu_353.0
# Model_pojazdu_356
# Model_pojazdu_360
# Model_pojazdu_370 Z
# Model_pojazdu_3GT
# Model_pojazdu_4
# Model_pojazdu_4-Runner
# Model_pojazdu_400
# Model_pojazdu_4007
# Model_pojazdu_4008
# Model_pojazdu_402
# Model_pojazdu_403
# Model_pojazdu_405
# Model_pojazdu_406
# Model_pojazdu_407
# Model_pojazdu_408
# Model_pojazdu_416
# Model_pojazdu_4200
# Model_pojazdu_45
# Model_pojazdu_452
# Model_pojazdu_458 Italia
# Model_pojazdu_488
# Model_pojazdu_488 Pista
# Model_pojazdu_4C
# Model_pojazdu_5
# Model_pojazdu_500
# Model_pojazdu_5008
# Model_pojazdu_500L
# Model_pojazdu_500X
# Model_pojazdu_508
# Model_pojazdu_57
# Model_pojazdu_570 GT
# Model_pojazdu_570S Coupe
# Model_pojazdu_570S Spider
# Model_pojazdu_575
# Model_pojazdu_595
# Model_pojazdu_599GTB
# Model_pojazdu_5GT
# Model_pojazdu_6
# Model_pojazdu_600
# Model_pojazdu_600LT Spider
# Model_pojazdu_601
# Model_pojazdu_605
# Model_pojazdu_607
# Model_pojazdu_620
# Model_pojazdu_626
# Model_pojazdu_69
# Model_pojazdu_6GT
# Model_pojazdu_718 Boxster
# Model_pojazdu_718 Cayman
# Model_pojazdu_720S Coupe
# Model_pojazdu_720S Spider
# Model_pojazdu_744
# Model_pojazdu_75
# Model_pojazdu_750
# Model_pojazdu_80
# Model_pojazdu_807
# Model_pojazdu_812 Superfast
# Model_pojazdu_827
# Model_pojazdu_850
# Model_pojazdu_9
# Model_pojazdu_9-2X
# Model_pojazdu_9-3
# Model_pojazdu_9-3X
# Model_pojazdu_9-5
# Model_pojazdu_9-7X
# Model_pojazdu_90
# Model_pojazdu_900
# Model_pojazdu_9000
# Model_pojazdu_911
# Model_pojazdu_914
# Model_pojazdu_924
# Model_pojazdu_928
# Model_pojazdu_929
# Model_pojazdu_944
# Model_pojazdu_945
# Model_pojazdu_96
# Model_pojazdu_965
# Model_pojazdu_968
# Model_pojazdu_A1
# Model_pojazdu_A110
# Model_pojazdu_A2
# Model_pojazdu_A3
# Model_pojazdu_A4
# Model_pojazdu_A4 Allroad
# Model_pojazdu_A5
# Model_pojazdu_A6
# Model_pojazdu_A6 Allroad
# Model_pojazdu_A7
# Model_pojazdu_A721
# Model_pojazdu_A741
# Model_pojazdu_A751
# Model_pojazdu_A8
# Model_pojazdu_AMG GT
# Model_pojazdu_ASX
# Model_pojazdu_ATS
# Model_pojazdu_AX
# Model_pojazdu_Accent
# Model_pojazdu_Accord
# Model_pojazdu_Across
# Model_pojazdu_Actyon
# Model_pojazdu_Adam
# Model_pojazdu_Agila
# Model_pojazdu_Alaskan
# Model_pojazdu_Albea
# Model_pojazdu_Alero
# Model_pojazdu_Alhambra
# Model_pojazdu_Allegro
# Model_pojazdu_Almera
# Model_pojazdu_Almera Tino
# Model_pojazdu_Altea
# Model_pojazdu_Altea XL
# Model_pojazdu_Altima
# Model_pojazdu_Alto
# Model_pojazdu_Amarok
# Model_pojazdu_Ambra
# Model_pojazdu_Ampera
# Model_pojazdu_Antara
# Model_pojazdu_Apache
# Model_pojazdu_Arnage
# Model_pojazdu_Arona
# Model_pojazdu_Arosa
# Model_pojazdu_Arteon
# Model_pojazdu_Ascona
# Model_pojazdu_Aspen
# Model_pojazdu_Astra
# Model_pojazdu_Astro
# Model_pojazdu_Ateca
# Model_pojazdu_Atlas
# Model_pojazdu_Atos
# Model_pojazdu_Atu
# Model_pojazdu_Auris
# Model_pojazdu_Aurora
# Model_pojazdu_Avalanche
# Model_pojazdu_Avalon
# Model_pojazdu_Avantime
# Model_pojazdu_Avenger
# Model_pojazdu_Avensis
# Model_pojazdu_Avensis Verso
# Model_pojazdu_Aventador
# Model_pojazdu_Aveo
# Model_pojazdu_Aviator
# Model_pojazdu_Aygo
# Model_pojazdu_Azera
# Model_pojazdu_B-MAX
# Model_pojazdu_B9 Tribeca
# Model_pojazdu_BLS
# Model_pojazdu_BRZ
# Model_pojazdu_BT-50
# Model_pojazdu_BX
# Model_pojazdu_Baja
# Model_pojazdu_Baleno
# Model_pojazdu_Barchetta
# Model_pojazdu_Beetle
# Model_pojazdu_Bentayga
# Model_pojazdu_Berlingo
# Model_pojazdu_Bianchina
# Model_pojazdu_Bipper
# Model_pojazdu_Biturbo
# Model_pojazdu_Blazer
# Model_pojazdu_Bluebird
# Model_pojazdu_Bolt
# Model_pojazdu_Bonneville
# Model_pojazdu_Bora
# Model_pojazdu_Bosto
# Model_pojazdu_Boxer
# Model_pojazdu_Boxster
# Model_pojazdu_Brava
# Model_pojazdu_Bravada
# Model_pojazdu_Bravo
# Model_pojazdu_Brera
# Model_pojazdu_Brougham
# Model_pojazdu_C-10
# Model_pojazdu_C-Crosser
# Model_pojazdu_C-Elysée
# Model_pojazdu_C-HR
# Model_pojazdu_C-MAX
# Model_pojazdu_C1
# Model_pojazdu_C2
# Model_pojazdu_C3
# Model_pojazdu_C3 Aircross
# Model_pojazdu_C3 Picasso
# Model_pojazdu_C3 Pluriel
# Model_pojazdu_C30
# Model_pojazdu_C4
# Model_pojazdu_C4 Aircross
# Model_pojazdu_C4 Cactus
# Model_pojazdu_C4 Grand Picasso
# Model_pojazdu_C4 Picasso
# Model_pojazdu_C4 SpaceTourer
# Model_pojazdu_C5
# Model_pojazdu_C5 Aircross
# Model_pojazdu_C6
# Model_pojazdu_C70
# Model_pojazdu_C8
# Model_pojazdu_CC
# Model_pojazdu_CH22 Barooder
# Model_pojazdu_CH26
# Model_pojazdu_CH32
# Model_pojazdu_CJ
# Model_pojazdu_CL
# Model_pojazdu_CLA
# Model_pojazdu_CLC
# Model_pojazdu_CLK
# Model_pojazdu_CLS
# Model_pojazdu_CR-V
# Model_pojazdu_CR-Z
# Model_pojazdu_CRX
# Model_pojazdu_CT
# Model_pojazdu_CT6
# Model_pojazdu_CTS
# Model_pojazdu_CX-3
# Model_pojazdu_CX-30
# Model_pojazdu_CX-5
# Model_pojazdu_CX-7
# Model_pojazdu_CX-9
# Model_pojazdu_Cabriolet
# Model_pojazdu_Caddy
# Model_pojazdu_Caliber
# Model_pojazdu_Calibra
# Model_pojazdu_California
# Model_pojazdu_Camaro
# Model_pojazdu_Campo
# Model_pojazdu_Camry
# Model_pojazdu_Camry Solara
# Model_pojazdu_Capri
# Model_pojazdu_Caprice
# Model_pojazdu_Captiva
# Model_pojazdu_Captur
# Model_pojazdu_Caravan
# Model_pojazdu_Caravelle
# Model_pojazdu_Carens
# Model_pojazdu_Carina
# Model_pojazdu_Carisma
# Model_pojazdu_Carnival
# Model_pojazdu_Caro
# Model_pojazdu_Cascada
# Model_pojazdu_Catalina
# Model_pojazdu_Cayenne
# Model_pojazdu_Cayman
# Model_pojazdu_Ceed
# Model_pojazdu_Celerio
# Model_pojazdu_Celica
# Model_pojazdu_Century
# Model_pojazdu_Cerato
# Model_pojazdu_Chairman
# Model_pojazdu_Challenger
# Model_pojazdu_Charade
# Model_pojazdu_Charger
# Model_pojazdu_Cherokee
# Model_pojazdu_Chevy Van
# Model_pojazdu_Chieftain
# Model_pojazdu_Cinquecento
# Model_pojazdu_Citan
# Model_pojazdu_Citigo
# Model_pojazdu_City
# Model_pojazdu_Civic
# Model_pojazdu_Clarus
# Model_pojazdu_Clio
# Model_pojazdu_Clubman
# Model_pojazdu_Colorado
# Model_pojazdu_Colt
# Model_pojazdu_Comanche
# Model_pojazdu_Combo
# Model_pojazdu_Commander
# Model_pojazdu_Commodore
# Model_pojazdu_Compass
# Model_pojazdu_Continental
# Model_pojazdu_Continental Flying Spur
# Model_pojazdu_Continental GT
# Model_pojazdu_Cooper
# Model_pojazdu_Cooper S
# Model_pojazdu_Cordoba
# Model_pojazdu_Corniche
# Model_pojazdu_Corolla
# Model_pojazdu_Corolla Verso
# Model_pojazdu_Corsa
# Model_pojazdu_Corvette
# Model_pojazdu_Cougar
# Model_pojazdu_Countach
# Model_pojazdu_Countryman
# Model_pojazdu_Coupe
# Model_pojazdu_Courier
# Model_pojazdu_Crafter
# Model_pojazdu_Cressida
# Model_pojazdu_Croma
# Model_pojazdu_Crossfire
# Model_pojazdu_Crossland X
# Model_pojazdu_Crossline
# Model_pojazdu_Crossover
# Model_pojazdu_Crosswagon
# Model_pojazdu_Crown
# Model_pojazdu_Cruze
# Model_pojazdu_Cube
# Model_pojazdu_Cullinan
# Model_pojazdu_Cuore
# Model_pojazdu_Cutlass
# Model_pojazdu_D-Max
# Model_pojazdu_DB11
# Model_pojazdu_DB7
# Model_pojazdu_DB9
# Model_pojazdu_DBS Superleggera
# Model_pojazdu_DBX
# Model_pojazdu_DS
# Model_pojazdu_DS 3
# Model_pojazdu_DS 3 Crossback
# Model_pojazdu_DS 4
# Model_pojazdu_DS 4 Crossback
# Model_pojazdu_DS 5
# Model_pojazdu_DS 7 Crossback
# Model_pojazdu_DS3
# Model_pojazdu_DS4
# Model_pojazdu_DS5
# Model_pojazdu_DTS
# Model_pojazdu_DUE
# Model_pojazdu_DUE First
# Model_pojazdu_Daimler
# Model_pojazdu_Dakota
# Model_pojazdu_Dart
# Model_pojazdu_Defender
# Model_pojazdu_Delta
# Model_pojazdu_Delta 88
# Model_pojazdu_Demio
# Model_pojazdu_Deville
# Model_pojazdu_Diablo
# Model_pojazdu_Discovery
# Model_pojazdu_Discovery Sport
# Model_pojazdu_Doblo
# Model_pojazdu_Dokker
# Model_pojazdu_Dokker Van
# Model_pojazdu_Ducato
# Model_pojazdu_Durango
# Model_pojazdu_Duster
# Model_pojazdu_E-Pace
# Model_pojazdu_E-Type
# Model_pojazdu_EDGE
# Model_pojazdu_EQA
# Model_pojazdu_EQC
# Model_pojazdu_EQV
# Model_pojazdu_ES
# Model_pojazdu_EX
# Model_pojazdu_Eclipse
# Model_pojazdu_Eclipse Cross
# Model_pojazdu_EcoSport
# Model_pojazdu_Econoline
# Model_pojazdu_Eighty - Eight
# Model_pojazdu_El Camino
# Model_pojazdu_Elantra
# Model_pojazdu_Eldorado
# Model_pojazdu_Electra
# Model_pojazdu_Enclave
# Model_pojazdu_Endeavor
# Model_pojazdu_Envoy
# Model_pojazdu_Enyaq
# Model_pojazdu_Eos
# Model_pojazdu_Epica
# Model_pojazdu_Equinox
# Model_pojazdu_Escalade
# Model_pojazdu_Escape
# Model_pojazdu_Escort
# Model_pojazdu_Espace
# Model_pojazdu_Espero
# Model_pojazdu_Evanda
# Model_pojazdu_Evasion
# Model_pojazdu_Evora
# Model_pojazdu_Excursion
# Model_pojazdu_Exeo
# Model_pojazdu_Expedition
# Model_pojazdu_Expert
# Model_pojazdu_Explorer
# Model_pojazdu_Express
# Model_pojazdu_F-Pace
# Model_pojazdu_F-Type
# Model_pojazdu_F12berlinetta
# Model_pojazdu_F150
# Model_pojazdu_F250
# Model_pojazdu_F350
# Model_pojazdu_F355
# Model_pojazdu_F360
# Model_pojazdu_F430
# Model_pojazdu_F8 Tributo
# Model_pojazdu_FF
# Model_pojazdu_FJ
# Model_pojazdu_FR-V
# Model_pojazdu_FX
# Model_pojazdu_Fabia
# Model_pojazdu_Fairlane
# Model_pojazdu_Favorit
# Model_pojazdu_Felicia
# Model_pojazdu_Fengon 5
# Model_pojazdu_Feroza
# Model_pojazdu_Fiero
# Model_pojazdu_Fiesta
# Model_pojazdu_Fiorino
# Model_pojazdu_Firebird
# Model_pojazdu_Fleetwood
# Model_pojazdu_Flex
# Model_pojazdu_Fluence
# Model_pojazdu_Focus
# Model_pojazdu_Focus C-Max
# Model_pojazdu_Forester
# Model_pojazdu_Forfour
# Model_pojazdu_Forman
# Model_pojazdu_Formentor
# Model_pojazdu_Fortwo
# Model_pojazdu_Fox
# Model_pojazdu_Freelander
# Model_pojazdu_Freemont
# Model_pojazdu_Freestar
# Model_pojazdu_Frontera
# Model_pojazdu_Frontier
# Model_pojazdu_Fuego
# Model_pojazdu_Fullback
# Model_pojazdu_Fulvia
# Model_pojazdu_Fury
# Model_pojazdu_Fusion
# Model_pojazdu_G
# Model_pojazdu_G3X Justy
# Model_pojazdu_GAZ-21
# Model_pojazdu_GAZ-24
# Model_pojazdu_GL
# Model_pojazdu_GLA
# Model_pojazdu_GLB
# Model_pojazdu_GLC
# Model_pojazdu_GLE
# Model_pojazdu_GLK
# Model_pojazdu_GLS
# Model_pojazdu_GS
# Model_pojazdu_GT
# Model_pojazdu_GT-R
# Model_pojazdu_GT86
# Model_pojazdu_GTC4Lusso
# Model_pojazdu_GTO
# Model_pojazdu_GTV
# Model_pojazdu_GX
# Model_pojazdu_Galant
# Model_pojazdu_Galaxy
# Model_pojazdu_Gallardo
# Model_pojazdu_Galloper
# Model_pojazdu_Gamma
# Model_pojazdu_Garbus
# Model_pojazdu_Genesis
# Model_pojazdu_Genesis Coupe
# Model_pojazdu_Getz
# Model_pojazdu_Ghibli
# Model_pojazdu_Ghost
# Model_pojazdu_Giulia
# Model_pojazdu_Giulietta
# Model_pojazdu_Gladiator
# Model_pojazdu_Glory 580
# Model_pojazdu_Golf
# Model_pojazdu_Golf Plus
# Model_pojazdu_Golf Sportsvan
# Model_pojazdu_GranCabrio
# Model_pojazdu_GranTurismo
# Model_pojazdu_Granada
# Model_pojazdu_Grand C-MAX
# Model_pojazdu_Grand Caravan
# Model_pojazdu_Grand Cherokee
# Model_pojazdu_Grand Espace
# Model_pojazdu_Grand Santa Fe
# Model_pojazdu_Grand Scenic
# Model_pojazdu_Grand Vitara
# Model_pojazdu_Grand Voyager
# Model_pojazdu_Grand-Am
# Model_pojazdu_Grand-Prix
# Model_pojazdu_Grande Punto
# Model_pojazdu_Grandeur
# Model_pojazdu_Grandis
# Model_pojazdu_Grandland X
# Model_pojazdu_H-1
# Model_pojazdu_H-1 Starex
# Model_pojazdu_H1
# Model_pojazdu_H2
# Model_pojazdu_H3
# Model_pojazdu_HHR
# Model_pojazdu_HQ
# Model_pojazdu_HR-V
# Model_pojazdu_HS 250h
# Model_pojazdu_Hiace
# Model_pojazdu_Highland X
# Model_pojazdu_Highlander
# Model_pojazdu_Hilux
# Model_pojazdu_Honker
# Model_pojazdu_Horizon
# Model_pojazdu_Huracan
# Model_pojazdu_I-Pace
# Model_pojazdu_I30
# Model_pojazdu_ID.3
# Model_pojazdu_ID.4
# Model_pojazdu_IONIQ
# Model_pojazdu_IS
# Model_pojazdu_IXO
# Model_pojazdu_Ibiza
# Model_pojazdu_Idea
# Model_pojazdu_Ignis
# Model_pojazdu_Impala
# Model_pojazdu_Impreza
# Model_pojazdu_Indica
# Model_pojazdu_Insight
# Model_pojazdu_Insignia
# Model_pojazdu_Integra
# Model_pojazdu_Interstar
# Model_pojazdu_JS RC
# Model_pojazdu_JS50
# Model_pojazdu_JS50L
# Model_pojazdu_Jazz
# Model_pojazdu_Jetta
# Model_pojazdu_Jimny
# Model_pojazdu_Joice
# Model_pojazdu_Journey
# Model_pojazdu_Juke
# Model_pojazdu_Jumper
# Model_pojazdu_Jumpy Combi
# Model_pojazdu_Justy
# Model_pojazdu_K1500
# Model_pojazdu_KA
# Model_pojazdu_Ka+
# Model_pojazdu_Kadett
# Model_pojazdu_Kadjar
# Model_pojazdu_Kafer
# Model_pojazdu_Kalina
# Model_pojazdu_Kalos
# Model_pojazdu_Kamiq
# Model_pojazdu_Kangoo
# Model_pojazdu_Kappa
# Model_pojazdu_Karl
# Model_pojazdu_Karmann Ghia
# Model_pojazdu_Karoq
# Model_pojazdu_King Cab
# Model_pojazdu_Kizashi
# Model_pojazdu_Klasa A
# Model_pojazdu_Klasa B
# Model_pojazdu_Klasa C
# Model_pojazdu_Klasa E
# Model_pojazdu_Klasa G
# Model_pojazdu_Klasa R
# Model_pojazdu_Klasa S
# Model_pojazdu_Klasa V
# Model_pojazdu_Klasa X
# Model_pojazdu_Kodiaq
# Model_pojazdu_Koleos
# Model_pojazdu_Kona
# Model_pojazdu_Korando
# Model_pojazdu_Kubistar
# Model_pojazdu_Kuga
# Model_pojazdu_Kyron
# Model_pojazdu_L200
# Model_pojazdu_L300
# Model_pojazdu_L400
# Model_pojazdu_LC
# Model_pojazdu_LJ
# Model_pojazdu_LS
# Model_pojazdu_LT
# Model_pojazdu_LX
# Model_pojazdu_Lacetti
# Model_pojazdu_Lacrosse
# Model_pojazdu_Laguna
# Model_pojazdu_Lancer
# Model_pojazdu_Lancer Evolution
# Model_pojazdu_Land Cruiser
# Model_pojazdu_Lanos
# Model_pojazdu_Latitude
# Model_pojazdu_Laurel
# Model_pojazdu_Le Baron
# Model_pojazdu_Le Sabre
# Model_pojazdu_Leaf
# Model_pojazdu_Legacy
# Model_pojazdu_Leganza
# Model_pojazdu_Legend
# Model_pojazdu_Leon
# Model_pojazdu_Leon Sportstourer
# Model_pojazdu_Levante
# Model_pojazdu_Levorg
# Model_pojazdu_Liana
# Model_pojazdu_Liberty
# Model_pojazdu_Ligier
# Model_pojazdu_Linea
# Model_pojazdu_Lodgy
# Model_pojazdu_Logan
# Model_pojazdu_Logan Van
# Model_pojazdu_Lupo
# Model_pojazdu_Lybra
# Model_pojazdu_M
# Model_pojazdu_M-20
# Model_pojazdu_M.GO
# Model_pojazdu_M14
# Model_pojazdu_M2
# Model_pojazdu_M3
# Model_pojazdu_M4
# Model_pojazdu_M5
# Model_pojazdu_M6
# Model_pojazdu_M8
# Model_pojazdu_MC
# Model_pojazdu_MDX
# Model_pojazdu_MG
# Model_pojazdu_MGA
# Model_pojazdu_MGB
# Model_pojazdu_MGF
# Model_pojazdu_MK II
# Model_pojazdu_MKX
# Model_pojazdu_MKZ
# Model_pojazdu_ML
# Model_pojazdu_MP4-12C
# Model_pojazdu_MPV
# Model_pojazdu_MR2
# Model_pojazdu_MUSSO
# Model_pojazdu_MX-3
# Model_pojazdu_MX-30
# Model_pojazdu_MX-5
# Model_pojazdu_Macan
# Model_pojazdu_Magentis
# Model_pojazdu_Magnum
# Model_pojazdu_Malibu
# Model_pojazdu_Manta
# Model_pojazdu_Marbella
# Model_pojazdu_Marea
# Model_pojazdu_Mark
# Model_pojazdu_Mark LT
# Model_pojazdu_Marquis
# Model_pojazdu_Massif
# Model_pojazdu_Master
# Model_pojazdu_Materia
# Model_pojazdu_Matiz
# Model_pojazdu_Matrix
# Model_pojazdu_Maverick
# Model_pojazdu_Maxima
# Model_pojazdu_Media
# Model_pojazdu_Megane
# Model_pojazdu_Mercury
# Model_pojazdu_Meriva
# Model_pojazdu_Micra
# Model_pojazdu_Midget
# Model_pojazdu_Mii
# Model_pojazdu_Millenia
# Model_pojazdu_Mini
# Model_pojazdu_Mito
# Model_pojazdu_Model 3
# Model_pojazdu_Model S
# Model_pojazdu_Model X
# Model_pojazdu_Modus
# Model_pojazdu_Mokka
# Model_pojazdu_Mondeo
# Model_pojazdu_Mondial
# Model_pojazdu_Monte Carlo
# Model_pojazdu_Monterey
# Model_pojazdu_Montero
# Model_pojazdu_Monza
# Model_pojazdu_Movano
# Model_pojazdu_Mulsanne
# Model_pojazdu_Multipla
# Model_pojazdu_Multivan
# Model_pojazdu_Murano
# Model_pojazdu_Murcielago
# Model_pojazdu_Musa
# Model_pojazdu_Mustang
# Model_pojazdu_Mustang Mach-E
# Model_pojazdu_NP300 Pickup
# Model_pojazdu_NV200
# Model_pojazdu_NV300
# Model_pojazdu_NX
# Model_pojazdu_Navara
# Model_pojazdu_Navigator
# Model_pojazdu_Nemo
# Model_pojazdu_Neon
# Model_pojazdu_New Beetle
# Model_pojazdu_New Yorker
# Model_pojazdu_Niro
# Model_pojazdu_Nitro
# Model_pojazdu_Niva
# Model_pojazdu_Note
# Model_pojazdu_Nova
# Model_pojazdu_Nubira
# Model_pojazdu_ONE
# Model_pojazdu_OUTBACK
# Model_pojazdu_Octavia
# Model_pojazdu_Odyssey
# Model_pojazdu_Omega
# Model_pojazdu_Opirus
# Model_pojazdu_Optima
# Model_pojazdu_Orion
# Model_pojazdu_Orlando
# Model_pojazdu_Other
# Model_pojazdu_Outlander
# Model_pojazdu_Outlook
# Model_pojazdu_P 50
# Model_pojazdu_PS-10
# Model_pojazdu_PT Cruiser
# Model_pojazdu_Paceman
# Model_pojazdu_Pacifica
# Model_pojazdu_Pajero
# Model_pojazdu_Pajero Pinin
# Model_pojazdu_Palio
# Model_pojazdu_Panamera
# Model_pojazdu_Panda
# Model_pojazdu_Park Avenue
# Model_pojazdu_Park Ward
# Model_pojazdu_Partner
# Model_pojazdu_Paseo
# Model_pojazdu_Passat
# Model_pojazdu_Passat CC
# Model_pojazdu_Pathfinder
# Model_pojazdu_Patriot
# Model_pojazdu_Patrol
# Model_pojazdu_Phaeton
# Model_pojazdu_Phantom
# Model_pojazdu_Phedra
# Model_pojazdu_Picanto
# Model_pojazdu_Pickup
# Model_pojazdu_Pilot
# Model_pojazdu_Pixo
# Model_pojazdu_Polo
# Model_pojazdu_Pony
# Model_pojazdu_Portofino
# Model_pojazdu_Praktik
# Model_pojazdu_Prelude
# Model_pojazdu_Premacy
# Model_pojazdu_Previa
# Model_pojazdu_Primastar
# Model_pojazdu_Primera
# Model_pojazdu_Prius
# Model_pojazdu_Prius+
# Model_pojazdu_ProAce
# Model_pojazdu_Pro_cee'd
# Model_pojazdu_Proace City
# Model_pojazdu_Proace City Verso
# Model_pojazdu_Proace Verso
# Model_pojazdu_Probe
# Model_pojazdu_Protege
# Model_pojazdu_Prowler
# Model_pojazdu_Pulsar
# Model_pojazdu_Puma
# Model_pojazdu_Punto
# Model_pojazdu_Punto 2012
# Model_pojazdu_Punto Evo
# Model_pojazdu_Q2
# Model_pojazdu_Q3
# Model_pojazdu_Q30
# Model_pojazdu_Q5
# Model_pojazdu_Q50
# Model_pojazdu_Q60
# Model_pojazdu_Q7
# Model_pojazdu_Q70
# Model_pojazdu_Q8
# Model_pojazdu_QX
# Model_pojazdu_QX30
# Model_pojazdu_QX50
# Model_pojazdu_QX60
# Model_pojazdu_QX70
# Model_pojazdu_QX80
# Model_pojazdu_Qashqai
# Model_pojazdu_Qashqai+2
# Model_pojazdu_Quattroporte
# Model_pojazdu_Qubo
# Model_pojazdu_Quest
# Model_pojazdu_R-20
# Model_pojazdu_R8
# Model_pojazdu_RAM
# Model_pojazdu_RAPID
# Model_pojazdu_RAV4
# Model_pojazdu_RC
# Model_pojazdu_RCZ
# Model_pojazdu_RDX
# Model_pojazdu_REXTON
# Model_pojazdu_RL
# Model_pojazdu_RS Q3
# Model_pojazdu_RS Q8
# Model_pojazdu_RS3
# Model_pojazdu_RS4
# Model_pojazdu_RS5
# Model_pojazdu_RS6
# Model_pojazdu_RS7
# Model_pojazdu_RX
# Model_pojazdu_RX-7
# Model_pojazdu_RX-8
# Model_pojazdu_Ranchero
# Model_pojazdu_Range Rover
# Model_pojazdu_Range Rover Evoque
# Model_pojazdu_Range Rover Sport
# Model_pojazdu_Range Rover Velar
# Model_pojazdu_Ranger
# Model_pojazdu_Ranger Raptor
# Model_pojazdu_Rapide
# Model_pojazdu_Reatta
# Model_pojazdu_Regal
# Model_pojazdu_Regency
# Model_pojazdu_Rekord
# Model_pojazdu_Rendezvous
# Model_pojazdu_Renegade
# Model_pojazdu_Rezzo
# Model_pojazdu_Ridgeline
# Model_pojazdu_Rifter
# Model_pojazdu_Rio
# Model_pojazdu_Riviera
# Model_pojazdu_Road Runner
# Model_pojazdu_Roadline
# Model_pojazdu_Roadmaster
# Model_pojazdu_Roadster
# Model_pojazdu_Rocky
# Model_pojazdu_Rodius
# Model_pojazdu_Rogue
# Model_pojazdu_Roma
# Model_pojazdu_Ronda
# Model_pojazdu_Roomster
# Model_pojazdu_Routan
# Model_pojazdu_S 2000
# Model_pojazdu_S-10
# Model_pojazdu_S-Max
# Model_pojazdu_S-Type
# Model_pojazdu_S-Type R
# Model_pojazdu_S1
# Model_pojazdu_S3
# Model_pojazdu_S4
# Model_pojazdu_S40
# Model_pojazdu_S5
# Model_pojazdu_S6
# Model_pojazdu_S60
# Model_pojazdu_S7
# Model_pojazdu_S70
# Model_pojazdu_S8
# Model_pojazdu_S80
# Model_pojazdu_S90
# Model_pojazdu_SC
# Model_pojazdu_SJ
# Model_pojazdu_SL
# Model_pojazdu_SLC
# Model_pojazdu_SLK
# Model_pojazdu_SLS
# Model_pojazdu_SQ5
# Model_pojazdu_SQ7
# Model_pojazdu_SQ8
# Model_pojazdu_SRX
# Model_pojazdu_STS
# Model_pojazdu_SVX
# Model_pojazdu_SX4
# Model_pojazdu_SX4 S-Cross
# Model_pojazdu_Safari
# Model_pojazdu_Safrane
# Model_pojazdu_Samara
# Model_pojazdu_Samurai
# Model_pojazdu_Sandero
# Model_pojazdu_Sandero Stepway
# Model_pojazdu_Santa Fe
# Model_pojazdu_Santana
# Model_pojazdu_Savana
# Model_pojazdu_Saxo
# Model_pojazdu_Scala
# Model_pojazdu_Scenic
# Model_pojazdu_Scenic Conquest
# Model_pojazdu_Scenic RX4
# Model_pojazdu_Scirocco
# Model_pojazdu_Scorpio
# Model_pojazdu_Scouty
# Model_pojazdu_Scouty R
# Model_pojazdu_Scudo
# Model_pojazdu_Sebring
# Model_pojazdu_Sedici
# Model_pojazdu_Sedona
# Model_pojazdu_Seicento
# Model_pojazdu_Senova X25
# Model_pojazdu_Senova X35
# Model_pojazdu_Senova X55
# Model_pojazdu_Sentra
# Model_pojazdu_Sequoia
# Model_pojazdu_Seria 1
# Model_pojazdu_Seria 2
# Model_pojazdu_Seria 200
# Model_pojazdu_Seria 3
# Model_pojazdu_Seria 4
# Model_pojazdu_Seria 400
# Model_pojazdu_Seria 5
# Model_pojazdu_Seria 500
# Model_pojazdu_Seria 6
# Model_pojazdu_Seria 7
# Model_pojazdu_Seria 700
# Model_pojazdu_Seria 8
# Model_pojazdu_Seria 900
# Model_pojazdu_Seville
# Model_pojazdu_Sharan
# Model_pojazdu_Shuma
# Model_pojazdu_Siena
# Model_pojazdu_Sienna
# Model_pojazdu_Sierra
# Model_pojazdu_Sigma
# Model_pojazdu_Signum
# Model_pojazdu_Silver Shadow
# Model_pojazdu_Silver Spirit
# Model_pojazdu_Silver Spur
# Model_pojazdu_Silverado
# Model_pojazdu_Sintra
# Model_pojazdu_Sirion
# Model_pojazdu_Skyline
# Model_pojazdu_Sonata
# Model_pojazdu_Sonica
# Model_pojazdu_Sorento
# Model_pojazdu_Soul
# Model_pojazdu_Space Gear
# Model_pojazdu_Space Runner
# Model_pojazdu_Space Star
# Model_pojazdu_Space Wagon
# Model_pojazdu_SpaceTourer
# Model_pojazdu_Spark
# Model_pojazdu_Speedster
# Model_pojazdu_Spider
# Model_pojazdu_Spitfire
# Model_pojazdu_Splash
# Model_pojazdu_Sportage
# Model_pojazdu_Sportwagon
# Model_pojazdu_Sprinter
# Model_pojazdu_Starlet
# Model_pojazdu_Stelvio
# Model_pojazdu_Stilo
# Model_pojazdu_Stinger
# Model_pojazdu_Stonic
# Model_pojazdu_Strada
# Model_pojazdu_Stratus
# Model_pojazdu_Stream
# Model_pojazdu_Streetka
# Model_pojazdu_Streetwise
# Model_pojazdu_Suburban
# Model_pojazdu_Sulky
# Model_pojazdu_Sunny
# Model_pojazdu_Super Seven
# Model_pojazdu_Superb
# Model_pojazdu_Supra
# Model_pojazdu_Swace
# Model_pojazdu_Swift
# Model_pojazdu_T-Cross
# Model_pojazdu_T-Roc
# Model_pojazdu_TD
# Model_pojazdu_TF
# Model_pojazdu_TGE
# Model_pojazdu_TL
# Model_pojazdu_TR3
# Model_pojazdu_TR4
# Model_pojazdu_TR7
# Model_pojazdu_TSX
# Model_pojazdu_TT
# Model_pojazdu_TT RS
# Model_pojazdu_TT S
# Model_pojazdu_Tacoma
# Model_pojazdu_Tacuma
# Model_pojazdu_Tahoe
# Model_pojazdu_Talento
# Model_pojazdu_Talisman
# Model_pojazdu_Tarraco
# Model_pojazdu_Taunus
# Model_pojazdu_Taurus
# Model_pojazdu_Taycan
# Model_pojazdu_Tempra
# Model_pojazdu_Teramont
# Model_pojazdu_Terios
# Model_pojazdu_Terracan
# Model_pojazdu_Terrain
# Model_pojazdu_Terrano
# Model_pojazdu_Testarossa
# Model_pojazdu_Thalia
# Model_pojazdu_Thema
# Model_pojazdu_Thesis
# Model_pojazdu_Thunderbird
# Model_pojazdu_Tico
# Model_pojazdu_Tigra
# Model_pojazdu_Tiguan
# Model_pojazdu_Tiguan Allspace
# Model_pojazdu_Tiida
# Model_pojazdu_Tipo
# Model_pojazdu_Titan
# Model_pojazdu_Tivoli
# Model_pojazdu_Toledo
# Model_pojazdu_Toronado
# Model_pojazdu_Touareg
# Model_pojazdu_Touran
# Model_pojazdu_Tourneo Connect
# Model_pojazdu_Tourneo Courier
# Model_pojazdu_Tourneo Custom
# Model_pojazdu_Town & Country
# Model_pojazdu_Town Car
# Model_pojazdu_Trafic
# Model_pojazdu_Trailblazer
# Model_pojazdu_Trajet
# Model_pojazdu_Trans Am
# Model_pojazdu_Trans Sport
# Model_pojazdu_Transit
# Model_pojazdu_Transit Connect
# Model_pojazdu_Transit Courier
# Model_pojazdu_Transit Custom
# Model_pojazdu_Transporter
# Model_pojazdu_Traveller
# Model_pojazdu_Traverse
# Model_pojazdu_Trax
# Model_pojazdu_Trevis
# Model_pojazdu_Trezia
# Model_pojazdu_Tribeca
# Model_pojazdu_Tribute
# Model_pojazdu_Tucson
# Model_pojazdu_Tundra
# Model_pojazdu_Twingo
# Model_pojazdu_Twizy
# Model_pojazdu_UX
# Model_pojazdu_Ulysse
# Model_pojazdu_Uno
# Model_pojazdu_Urban Cruiser
# Model_pojazdu_Urus
# Model_pojazdu_V40
# Model_pojazdu_V50
# Model_pojazdu_V60
# Model_pojazdu_V70
# Model_pojazdu_V8 Vantage
# Model_pojazdu_V90
# Model_pojazdu_Vaneo
# Model_pojazdu_Vantage
# Model_pojazdu_Vectra
# Model_pojazdu_Vel Satis
# Model_pojazdu_Veloster
# Model_pojazdu_Venga
# Model_pojazdu_Vento
# Model_pojazdu_Venture
# Model_pojazdu_Venza
# Model_pojazdu_Verso
# Model_pojazdu_Verso S
# Model_pojazdu_Viano
# Model_pojazdu_Viper
# Model_pojazdu_Virgo
# Model_pojazdu_Vision
# Model_pojazdu_Vitara
# Model_pojazdu_Vito
# Model_pojazdu_Vivaro
# Model_pojazdu_Volt
# Model_pojazdu_Voyager
# Model_pojazdu_W123
# Model_pojazdu_W124 (1984-1993)
# Model_pojazdu_W201 (190)
# Model_pojazdu_WRX
# Model_pojazdu_Wagon R+
# Model_pojazdu_Wagoneer
# Model_pojazdu_Willys
# Model_pojazdu_Wind
# Model_pojazdu_Windstar
# Model_pojazdu_Wraith
# Model_pojazdu_Wrangler
# Model_pojazdu_X 1
# Model_pojazdu_X-90
# Model_pojazdu_X-Too
# Model_pojazdu_X-Too Max
# Model_pojazdu_X-Trail
# Model_pojazdu_X-Type
# Model_pojazdu_X1
# Model_pojazdu_X2
# Model_pojazdu_X3
# Model_pojazdu_X3 M
# Model_pojazdu_X4
# Model_pojazdu_X5
# Model_pojazdu_X5 M
# Model_pojazdu_X6
# Model_pojazdu_X6 M
# Model_pojazdu_X7
# Model_pojazdu_XC 40
# Model_pojazdu_XC 60
# Model_pojazdu_XC 70
# Model_pojazdu_XC 90
# Model_pojazdu_XCeed
# Model_pojazdu_XE
# Model_pojazdu_XF
# Model_pojazdu_XG 30
# Model_pojazdu_XJ
# Model_pojazdu_XJS
# Model_pojazdu_XJSC
# Model_pojazdu_XK
# Model_pojazdu_XK8
# Model_pojazdu_XL7
# Model_pojazdu_XLR
# Model_pojazdu_XLV
# Model_pojazdu_XM
# Model_pojazdu_XT5
# Model_pojazdu_XTS
# Model_pojazdu_XV
# Model_pojazdu_Xantia
# Model_pojazdu_Xedos
# Model_pojazdu_Xenon
# Model_pojazdu_Xsara
# Model_pojazdu_Xsara Picasso
# Model_pojazdu_YRV
# Model_pojazdu_Yaris
# Model_pojazdu_Yaris Verso
# Model_pojazdu_Yeti
# Model_pojazdu_Ypsilon
# Model_pojazdu_Yukon
# Model_pojazdu_Z3
# Model_pojazdu_Z4
# Model_pojazdu_ZAZ 1102
# Model_pojazdu_ZR
# Model_pojazdu_ZS
# Model_pojazdu_ZT
# Model_pojazdu_ZX
# Model_pojazdu_Zafira
# Model_pojazdu_Zoe
# Model_pojazdu_altul
# Model_pojazdu_e-tron
# Model_pojazdu_i-MiEV
# Model_pojazdu_i10
# Model_pojazdu_i20
# Model_pojazdu_i25
# Model_pojazdu_i3
# Model_pojazdu_i30 N
# Model_pojazdu_i40
# Model_pojazdu_i8
# Model_pojazdu_iOn
# Model_pojazdu_iQ
# Model_pojazdu_ix20
# Model_pojazdu_ix35
# Model_pojazdu_ix55
# Model_pojazdu_up!
# Model_pojazdu_xA
# Rodzaj_paliwa_Electric
# Rodzaj_paliwa_Ethanol
# Rodzaj_paliwa_Gasoline
# Rodzaj_paliwa_Gasoline + CNG
# Rodzaj_paliwa_Gasoline + LPG
# Rodzaj_paliwa_Hybrid
# Rodzaj_paliwa_Hydrogen
# Naped_4x4 (attached manually)
# Naped_4x4 (permanent)
# Naped_Front wheels
# Naped_Rear wheels
# Skrzynia_biegow_Manual
# Typ_nadwozia_city_cars
# Typ_nadwozia_compact
# Typ_nadwozia_convertible
# Typ_nadwozia_coupe
# Typ_nadwozia_minivan
# Typ_nadwozia_sedan
# Typ_nadwozia_small_cars
# Typ_nadwozia_station_wagon
# Kolor_black
# Kolor_blue
# Kolor_brown
# Kolor_burgundy
# Kolor_golden
# Kolor_gray
# Kolor_green
# Kolor_other
# Kolor_red
# Kolor_silver
# Kolor_violet
# Kolor_white
# Kolor_yellow

# %% [markdown]
# ### Ponowne podzielenie na zbiór treningowy i testowy

# %%
# Dzielimy na podstawie is_train i usuwamy ją
train_dataset = full_dataset_transformed[full_dataset_transformed['is_train'] == 1].drop(columns=['is_train'])
test_dataset = full_dataset_transformed[full_dataset_transformed['is_train'] == 0].drop(columns=['is_train'])

# %%
record_number_train = len(train_dataset)
record_number_test = len(test_dataset)

print(f"Liczba rekordów w grupie treningowej: {record_number_train}")
print(f"Liczba rekordów w grupie testowej: {record_number_test}")
# Out:
# Liczba rekordów w grupie treningowej: 135397
# Liczba rekordów w grupie testowej: 72907

# %% [markdown]
# ### Sprawdzenie, czy gotowe do ML

# %%
# Sprawdzenie typów danych
print(train_dataset.dtypes)

# Sprawdzenie wartości brakujących
print(train_dataset.isnull().sum())
# Out:
# ID               float64
# Cena             float64
# Stan             float64
# Rok_produkcji    float64
# Przebieg_km      float64
#                   ...
# Kolor_red          uint8
# Kolor_silver       uint8
# Kolor_violet       uint8
# Kolor_white        uint8
# Kolor_yellow       uint8
# Length: 1352, dtype: object
# ID               0
# Cena             0
# Stan             0
# Rok_produkcji    0
# Przebieg_km      0
#                 ..
# Kolor_red        0
# Kolor_silver     0
# Kolor_violet     0
# Kolor_white      0
# Kolor_yellow     0
# Length: 1352, dtype: int64

# %%
# Sprawdzenie typów danych
print(test_dataset.dtypes)

# Sprawdzenie wartości brakujących
print(test_dataset.isnull().sum())
# Out:
# ID               float64
# Cena             float64
# Stan             float64
# Rok_produkcji    float64
# Przebieg_km      float64
#                   ...
# Kolor_red          uint8
# Kolor_silver       uint8
# Kolor_violet       uint8
# Kolor_white        uint8
# Kolor_yellow       uint8
# Length: 1352, dtype: object
# ID                   0
# Cena             72907
# Stan                 0
# Rok_produkcji        0
# Przebieg_km          0
#                  ...
# Kolor_red            0
# Kolor_silver         0
# Kolor_violet         0
# Kolor_white          0
# Kolor_yellow         0
# Length: 1352, dtype: int64

# %%
# Usuwanie kolumny Cena z test_dataset, która jest pusta
test_dataset = test_dataset.drop(columns=['Cena'])

# %% [markdown]
# #### Nie ma object, czyli dane są gotowe do użycia

# %% [markdown]
# ## Zapis przygotowanych danych do csv

# %%
train_dataset.to_csv('train_dataset.csv', index=False)
test_dataset.to_csv('test_dataset.csv', index=False)
